# %% [markdown]
# # Shapley Mining - Main Notebook
#
# Ten notatnik oblicza wartości Shapleya dla procesów wydobytych z logów zdarzeń.
#
# Wszystkie funkcje zostały wydzielone do pakietu `Functions/`.

# %%
import sys
import os
import importlib

current_dir = os.getcwd()
functions_path = os.path.join(current_dir, "Functions")
if functions_path not in sys.path:
    sys.path.insert(0, functions_path)

modules_to_reload = [
    'Functions.shapley.shapley_calculations',
    'Functions.shapley',
    'Functions.coalition.coalition_builder',
    'Functions.players.player_enumeration',
    'Functions.pattern_operators.operators',
    'Functions.utils.imports',
]

for module_name in modules_to_reload:
    if module_name in sys.modules:
        try:
            importlib.reload(sys.modules[module_name])
            print(f"✓ Reloaded: {module_name}")
        except Exception as e:
            print(f"⚠ Could not reload {module_name}: {e}")

print("Module refresh completed!")
# Out:
# ✓ Reloaded: Functions.shapley.shapley_calculations
# ✓ Reloaded: Functions.shapley
# ✓ Reloaded: Functions.coalition.coalition_builder
# ✓ Reloaded: Functions.players.player_enumeration
# ✓ Reloaded: Functions.pattern_operators.operators
# ✓ Reloaded: Functions.utils.imports
# Module refresh completed!

# %%
from Functions.utils.imports import *
from Functions.data_loading import load_event_log, discover_tree_inductive, assign_tau_labels, LOG_PATHS, NOISE_LEVELS
from Functions.process_tree import enumerate_tau, count_nodes
from Functions.tree_conversion import tree_to_named_pattern_expression
from Functions.logical_spec import WorkflowPatternTemplate
from Functions.properties import extract_ini_fin, build_full_spec, evaluate_property
from Functions.shapley import shapley_mc_permutations, shapley_random_subsets

try:
    from Functions.shapley import shapley_mc_convergence, shapley_rs_convergence
    print("✓ Convergence functions imported successfully via __init__")
except ImportError:
    try:
        from Functions.shapley.shapley_calculations import shapley_mc_convergence, shapley_rs_convergence
    except ImportError as e:
        print(f"ebe ebe")
        shapley_mc_convergence = None
        shapley_rs_convergence = None

from Functions.io import persist_shapley_results, load_cached_shapley_results
from Functions.utils.constants import PATTERN_RULES_PATH

import warnings
warnings.filterwarnings("ignore")
# Out:
# ✓ Convergence functions imported successfully via __init__

# %% [markdown]
# ## Ładowanie danych i odkrywanie drzew procesu

# %%
# Ładowanie logów zdarzeń
EVENT_LOGS = {}
for name, path in LOG_PATHS.items():
    EVENT_LOGS[name] = load_event_log(path)

{k: len(v) for k, v in EVENT_LOGS.items()}
# Out:
# parsing log, completed traces ::   0%|          | 0/6 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/100000 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/13087 [00:00<?, ?it/s]
# {'running_example': 42, 'hospital_billing': 451359, 'bpi_2012': 262200}

# %%
# Odkrywanie drzew procesu
TREES = {}
for log_name, log_obj in EVENT_LOGS.items():
    for noise in NOISE_LEVELS:
        tree = discover_tree_inductive(log_obj, noise=noise)
        tree = assign_tau_labels(tree)
        TREES[(log_name, noise)] = tree

# %% [markdown]
# ## Konwersja drzew na wyrażenia wzorców

# %%
# Konwersja drzew na nazwane wyrażenia wzorców
PATTERNS = {}
for key, tree in TREES.items():
    named_expr = tree_to_named_pattern_expression(tree)
    PATTERNS[key] = named_expr

# %% [markdown]
# ## Ładowanie szablonów wzorców i generowanie specyfikacji

# %%
# Ładowanie szablonów wzorców
TEMPLATES = WorkflowPatternTemplate.load_pattern_property_set(PATTERN_RULES_PATH)

# Generowanie specyfikacji logicznych
SPECS = {}
INI_FIN = {}
for key, named_expr in PATTERNS.items():
    SPECS[key] = build_full_spec(named_expr, TEMPLATES)
    ini, fin = extract_ini_fin(named_expr, TEMPLATES)
    INI_FIN[key] = (ini, fin)

# %% [markdown]
# ## Obliczanie wartości Shapleya

# %%
# Obliczanie wartości Shapleya dla wszystkich konfiguracji
PROPERTIES = ["satisfiability", "liveness", "safety"]

# Sprawdź cache
SHAPLEY_RESULTS = load_cached_shapley_results()

if not SHAPLEY_RESULTS:
    SHAPLEY_RESULTS = []
    cfg_index = 0
    
    for (log_name, noise), named_expr in sorted(PATTERNS.items(), key=lambda kv: (kv[0][0], kv[0][1])):
        for prop in PROPERTIES:
            cfg_index += 1
            print(f"[{cfg_index:02d}/36] log={log_name}, noise={noise}, property={prop} -> START")
            
            # Monte Carlo Shapley
            phi_mc, meta_mc = shapley_mc_permutations(
                named_expr, TEMPLATES, prop,
                n_perm=1000, seed=2025, progress_every=25
            )
            
            # Random Subsets Shapley
            infl_rs, meta_rs = shapley_random_subsets(
                named_expr, TEMPLATES, prop,
                n_samples=2000, keep_frac_range=(0.5, 0.8), seed=2026, progress_every=100
            )
            
            SHAPLEY_RESULTS.append({
                "log": log_name,
                "noise": noise,
                "property": prop,
                "players": len(phi_mc),
                "mc_meta": meta_mc,
                "rs_meta": meta_rs,
                "phi_mc": phi_mc,
                "influence_rs": infl_rs
            })
            
            print(f"[{cfg_index:02d}/36] DONE\n")
    
    # Zapis wyników
    persist_shapley_results(SHAPLEY_RESULTS)
else:
    print(f"Using cached SHAPLEY_RESULTS ({len(SHAPLEY_RESULTS)} configurations)")
# Out:
# [01/36] log=bpi_2012, noise=0.0, property=satisfiability -> START
#       ... MC progress 25/1000 (players=45, cached=1088) [18.8s]
#       ... MC progress 50/1000 (players=45, cached=2162) [36.4s]
#       ... MC progress 75/1000 (players=45, cached=3222) [53.4s]
#       ... MC progress 100/1000 (players=45, cached=4277) [70.1s]
#       ... MC progress 125/1000 (players=45, cached=5320) [86.9s]
#       ... MC progress 150/1000 (players=45, cached=6363) [103.2s]
#       ... MC progress 175/1000 (players=45, cached=7407) [121.5s]
#       ... MC progress 200/1000 (players=45, cached=8450) [139.2s]
#       ... MC progress 225/1000 (players=45, cached=9487) [157.0s]
#       ... MC progress 250/1000 (players=45, cached=10528) [174.4s]
#       ... MC progress 275/1000 (players=45, cached=11566) [193.7s]
#       ... MC progress 300/1000 (players=45, cached=12610) [212.0s]
#       ... MC progress 325/1000 (players=45, cached=13647) [228.8s]
#       ... MC progress 350/1000 (players=45, cached=14681) [245.5s]
#       ... MC progress 375/1000 (players=45, cached=15711) [262.5s]
#       ... MC progress 400/1000 (players=45, cached=16737) [279.3s]
#       ... MC progress 425/1000 (players=45, cached=17765) [297.6s]
#       ... MC progress 450/1000 (players=45, cached=18796) [314.4s]
#       ... MC progress 475/1000 (players=45, cached=19827) [330.8s]
#       ... MC progress 500/1000 (players=45, cached=20853) [346.8s]
#       ... MC progress 525/1000 (players=45, cached=21877) [363.2s]
#       ... MC progress 550/1000 (players=45, cached=22905) [379.9s]
#       ... MC progress 575/1000 (players=45, cached=23929) [396.6s]
#       ... MC progress 600/1000 (players=45, cached=24949) [413.5s]
#       ... MC progress 625/1000 (players=45, cached=25971) [430.4s]
#       ... MC progress 650/1000 (players=45, cached=26984) [446.6s]
#       ... MC progress 675/1000 (players=45, cached=28011) [463.0s]
#       ... MC progress 700/1000 (players=45, cached=29035) [479.7s]
#       ... MC progress 725/1000 (players=45, cached=30052) [496.2s]
#       ... MC progress 750/1000 (players=45, cached=31070) [512.6s]
#       ... MC progress 775/1000 (players=45, cached=32091) [528.9s]
#       ... MC progress 800/1000 (players=45, cached=33114) [545.7s]
#       ... MC progress 825/1000 (players=45, cached=34138) [562.3s]
#       ... MC progress 850/1000 (players=45, cached=35159) [578.8s]
#       ... MC progress 875/1000 (players=45, cached=36170) [595.6s]
#       ... MC progress 900/1000 (players=45, cached=37192) [612.0s]
#       ... MC progress 925/1000 (players=45, cached=38208) [628.3s]
#       ... MC progress 950/1000 (players=45, cached=39227) [644.6s]
#       ... MC progress 975/1000 (players=45, cached=40245) [661.4s]
#       ... MC progress 1000/1000 (players=45, cached=41256) [677.7s]
#       ... RS progress 100/2000 (players=45) [3.1s]
#       ... RS progress 200/2000 (players=45) [6.4s]
#       ... RS progress 300/2000 (players=45) [9.6s]
#       ... RS progress 400/2000 (players=45) [13.3s]
#       ... RS progress 500/2000 (players=45) [16.6s]
#       ... RS progress 600/2000 (players=45) [19.8s]
#       ... RS progress 700/2000 (players=45) [22.9s]
#       ... RS progress 800/2000 (players=45) [25.9s]
#       ... RS progress 900/2000 (players=45) [29.1s]
#       ... RS progress 1000/2000 (players=45) [32.3s]
#       ... RS progress 1100/2000 (players=45) [35.5s]
#       ... RS progress 1200/2000 (players=45) [38.8s]
#       ... RS progress 1300/2000 (players=45) [42.1s]
#       ... RS progress 1400/2000 (players=45) [45.2s]
#       ... RS progress 1500/2000 (players=45) [48.5s]
#       ... RS progress 1600/2000 (players=45) [51.8s]
#       ... RS progress 1700/2000 (players=45) [55.1s]
#       ... RS progress 1800/2000 (players=45) [58.1s]
#       ... RS progress 1900/2000 (players=45) [61.3s]
#       ... RS progress 2000/2000 (players=45) [64.5s]
# [01/36] DONE
#
# [02/36] log=bpi_2012, noise=0.0, property=liveness -> START
#       ... MC progress 25/1000 (players=45, cached=1088) [22.3s]
#       ... MC progress 50/1000 (players=45, cached=2162) [44.3s]
#       ... MC progress 75/1000 (players=45, cached=3222) [64.6s]
#       ... MC progress 100/1000 (players=45, cached=4277) [84.9s]
#       ... MC progress 125/1000 (players=45, cached=5320) [104.9s]
#       ... MC progress 150/1000 (players=45, cached=6363) [124.9s]
#       ... MC progress 175/1000 (players=45, cached=7407) [143.4s]
#       ... MC progress 200/1000 (players=45, cached=8450) [162.0s]
#       ... MC progress 225/1000 (players=45, cached=9487) [180.3s]
#       ... MC progress 250/1000 (players=45, cached=10528) [198.8s]
#       ... MC progress 275/1000 (players=45, cached=11566) [217.5s]
#       ... MC progress 300/1000 (players=45, cached=12610) [235.8s]
#       ... MC progress 325/1000 (players=45, cached=13647) [254.1s]
#       ... MC progress 350/1000 (players=45, cached=14681) [272.0s]
#       ... MC progress 375/1000 (players=45, cached=15711) [290.5s]
#       ... MC progress 400/1000 (players=45, cached=16737) [308.4s]
#       ... MC progress 425/1000 (players=45, cached=17765) [326.1s]
#       ... MC progress 450/1000 (players=45, cached=18796) [343.8s]
#       ... MC progress 475/1000 (players=45, cached=19827) [361.8s]
#       ... MC progress 500/1000 (players=45, cached=20853) [379.5s]
#       ... MC progress 525/1000 (players=45, cached=21877) [398.7s]
#       ... MC progress 550/1000 (players=45, cached=22905) [417.4s]
#       ... MC progress 575/1000 (players=45, cached=23929) [436.2s]
#       ... MC progress 600/1000 (players=45, cached=24949) [454.9s]
#       ... MC progress 625/1000 (players=45, cached=25971) [473.4s]
#       ... MC progress 650/1000 (players=45, cached=26984) [491.5s]
#       ... MC progress 675/1000 (players=45, cached=28011) [509.9s]
#       ... MC progress 700/1000 (players=45, cached=29035) [528.8s]
#       ... MC progress 725/1000 (players=45, cached=30052) [547.2s]
#       ... MC progress 750/1000 (players=45, cached=31070) [565.8s]
#       ... MC progress 775/1000 (players=45, cached=32091) [583.9s]
#       ... MC progress 800/1000 (players=45, cached=33114) [602.4s]
#       ... MC progress 825/1000 (players=45, cached=34138) [620.9s]
#       ... MC progress 850/1000 (players=45, cached=35159) [639.1s]
#       ... MC progress 875/1000 (players=45, cached=36170) [657.3s]
#       ... MC progress 900/1000 (players=45, cached=37192) [675.3s]
#       ... MC progress 925/1000 (players=45, cached=38208) [693.4s]
#       ... MC progress 950/1000 (players=45, cached=39227) [711.7s]
#       ... MC progress 975/1000 (players=45, cached=40245) [730.3s]
#       ... MC progress 1000/1000 (players=45, cached=41256) [748.0s]
#       ... RS progress 100/2000 (players=45) [3.3s]
#       ... RS progress 200/2000 (players=45) [6.7s]
#       ... RS progress 300/2000 (players=45) [10.0s]
#       ... RS progress 400/2000 (players=45) [13.3s]
#       ... RS progress 500/2000 (players=45) [16.5s]
#       ... RS progress 600/2000 (players=45) [19.7s]
#       ... RS progress 700/2000 (players=45) [22.9s]
#       ... RS progress 800/2000 (players=45) [26.2s]
#       ... RS progress 900/2000 (players=45) [29.4s]
#       ... RS progress 1000/2000 (players=45) [32.6s]
#       ... RS progress 1100/2000 (players=45) [35.9s]
#       ... RS progress 1200/2000 (players=45) [39.3s]
#       ... RS progress 1300/2000 (players=45) [42.6s]
#       ... RS progress 1400/2000 (players=45) [45.8s]
#       ... RS progress 1500/2000 (players=45) [49.1s]
#       ... RS progress 1600/2000 (players=45) [52.5s]
#       ... RS progress 1700/2000 (players=45) [55.8s]
#       ... RS progress 1800/2000 (players=45) [59.0s]
#       ... RS progress 1900/2000 (players=45) [62.4s]
#       ... RS progress 2000/2000 (players=45) [65.8s]
# [02/36] DONE
#
# [03/36] log=bpi_2012, noise=0.0, property=safety -> START
#       ... MC progress 25/1000 (players=45, cached=1088) [21.6s]
#       ... MC progress 50/1000 (players=45, cached=2162) [42.9s]
#       ... MC progress 75/1000 (players=45, cached=3222) [63.1s]
#       ... MC progress 100/1000 (players=45, cached=4277) [82.8s]
#       ... MC progress 125/1000 (players=45, cached=5320) [102.3s]
#       ... MC progress 150/1000 (players=45, cached=6363) [121.4s]
#       ... MC progress 175/1000 (players=45, cached=7407) [140.6s]
#       ... MC progress 200/1000 (players=45, cached=8450) [159.7s]
#       ... MC progress 225/1000 (players=45, cached=9487) [178.7s]
#       ... MC progress 250/1000 (players=45, cached=10528) [196.7s]
#       ... MC progress 275/1000 (players=45, cached=11566) [213.9s]
#       ... MC progress 300/1000 (players=45, cached=12610) [230.9s]
#       ... MC progress 325/1000 (players=45, cached=13647) [247.9s]
#       ... MC progress 350/1000 (players=45, cached=14681) [264.6s]
#       ... MC progress 375/1000 (players=45, cached=15711) [281.5s]
#       ... MC progress 400/1000 (players=45, cached=16737) [298.0s]
#       ... MC progress 425/1000 (players=45, cached=17765) [314.5s]
#       ... MC progress 450/1000 (players=45, cached=18796) [330.9s]
#       ... MC progress 475/1000 (players=45, cached=19827) [347.5s]
#       ... MC progress 500/1000 (players=45, cached=20853) [363.9s]
#       ... MC progress 525/1000 (players=45, cached=21877) [380.4s]
#       ... MC progress 550/1000 (players=45, cached=22905) [397.1s]
#       ... MC progress 575/1000 (players=45, cached=23929) [414.0s]
#       ... MC progress 600/1000 (players=45, cached=24949) [430.8s]
#       ... MC progress 625/1000 (players=45, cached=25971) [447.2s]
#       ... MC progress 650/1000 (players=45, cached=26984) [463.5s]
#       ... MC progress 675/1000 (players=45, cached=28011) [480.0s]
#       ... MC progress 700/1000 (players=45, cached=29035) [496.9s]
#       ... MC progress 725/1000 (players=45, cached=30052) [513.6s]
#       ... MC progress 750/1000 (players=45, cached=31070) [530.3s]
#       ... MC progress 775/1000 (players=45, cached=32091) [546.6s]
#       ... MC progress 800/1000 (players=45, cached=33114) [563.3s]
#       ... MC progress 825/1000 (players=45, cached=34138) [579.9s]
#       ... MC progress 850/1000 (players=45, cached=35159) [596.2s]
#       ... MC progress 875/1000 (players=45, cached=36170) [612.7s]
#       ... MC progress 900/1000 (players=45, cached=37192) [628.9s]
#       ... MC progress 925/1000 (players=45, cached=38208) [645.1s]
#       ... MC progress 950/1000 (players=45, cached=39227) [661.4s]
#       ... MC progress 975/1000 (players=45, cached=40245) [678.0s]
#       ... MC progress 1000/1000 (players=45, cached=41256) [694.0s]
#       ... RS progress 100/2000 (players=45) [2.9s]
#       ... RS progress 200/2000 (players=45) [5.7s]
#       ... RS progress 300/2000 (players=45) [8.6s]
#       ... RS progress 400/2000 (players=45) [11.4s]
#       ... RS progress 500/2000 (players=45) [14.2s]
#       ... RS progress 600/2000 (players=45) [16.9s]
#       ... RS progress 700/2000 (players=45) [19.8s]
#       ... RS progress 800/2000 (players=45) [22.6s]
#       ... RS progress 900/2000 (players=45) [25.4s]
#       ... RS progress 1000/2000 (players=45) [28.2s]
#       ... RS progress 1100/2000 (players=45) [31.1s]
#       ... RS progress 1200/2000 (players=45) [33.9s]
#       ... RS progress 1300/2000 (players=45) [36.8s]
#       ... RS progress 1400/2000 (players=45) [39.6s]
#       ... RS progress 1500/2000 (players=45) [42.4s]
#       ... RS progress 1600/2000 (players=45) [45.2s]
#       ... RS progress 1700/2000 (players=45) [48.1s]
#       ... RS progress 1800/2000 (players=45) [50.8s]
#       ... RS progress 1900/2000 (players=45) [53.6s]
#       ... RS progress 2000/2000 (players=45) [56.5s]
# [03/36] DONE
#
# [04/36] log=bpi_2012, noise=0.25, property=satisfiability -> START
#       ... MC progress 25/1000 (players=34, cached=811) [11.3s]
#       ... MC progress 50/1000 (players=34, cached=1599) [21.8s]
#       ... MC progress 75/1000 (players=34, cached=2377) [32.1s]
#       ... MC progress 100/1000 (players=34, cached=3154) [41.9s]
#       ... MC progress 125/1000 (players=34, cached=3917) [51.1s]
#       ... MC progress 150/1000 (players=34, cached=4679) [60.5s]
#       ... MC progress 175/1000 (players=34, cached=5436) [69.4s]
#       ... MC progress 200/1000 (players=34, cached=6192) [78.2s]
#       ... MC progress 225/1000 (players=34, cached=6951) [87.5s]
#       ... MC progress 250/1000 (players=34, cached=7706) [96.3s]
#       ... MC progress 275/1000 (players=34, cached=8464) [104.9s]
#       ... MC progress 300/1000 (players=34, cached=9211) [113.6s]
#       ... MC progress 325/1000 (players=34, cached=9963) [122.2s]
#       ... MC progress 350/1000 (players=34, cached=10711) [130.9s]
#       ... MC progress 375/1000 (players=34, cached=11454) [139.4s]
#       ... MC progress 400/1000 (players=34, cached=12198) [147.8s]
#       ... MC progress 425/1000 (players=34, cached=12942) [156.2s]
#       ... MC progress 450/1000 (players=34, cached=13686) [164.4s]
#       ... MC progress 475/1000 (players=34, cached=14425) [172.7s]
#       ... MC progress 500/1000 (players=34, cached=15170) [180.8s]
#       ... MC progress 525/1000 (players=34, cached=15900) [188.7s]
#       ... MC progress 550/1000 (players=34, cached=16636) [196.6s]
#       ... MC progress 575/1000 (players=34, cached=17377) [204.6s]
#       ... MC progress 600/1000 (players=34, cached=18121) [212.7s]
#       ... MC progress 625/1000 (players=34, cached=18861) [220.4s]
#       ... MC progress 650/1000 (players=34, cached=19598) [228.5s]
#       ... MC progress 675/1000 (players=34, cached=20333) [236.4s]
#       ... MC progress 700/1000 (players=34, cached=21066) [244.4s]
#       ... MC progress 725/1000 (players=34, cached=21799) [252.1s]
#       ... MC progress 750/1000 (players=34, cached=22528) [259.9s]
#       ... MC progress 775/1000 (players=34, cached=23264) [267.7s]
#       ... MC progress 800/1000 (players=34, cached=23998) [275.5s]
#       ... MC progress 825/1000 (players=34, cached=24729) [283.0s]
#       ... MC progress 850/1000 (players=34, cached=25458) [290.6s]
#       ... MC progress 875/1000 (players=34, cached=26186) [298.4s]
#       ... MC progress 900/1000 (players=34, cached=26917) [306.3s]
#       ... MC progress 925/1000 (players=34, cached=27641) [314.1s]
#       ... MC progress 950/1000 (players=34, cached=28375) [321.4s]
#       ... MC progress 975/1000 (players=34, cached=29101) [328.7s]
#       ... MC progress 1000/1000 (players=34, cached=29830) [336.1s]
#       ... RS progress 100/2000 (players=34) [2.0s]
#       ... RS progress 200/2000 (players=34) [4.1s]
#       ... RS progress 300/2000 (players=34) [6.1s]
#       ... RS progress 400/2000 (players=34) [8.2s]
#       ... RS progress 500/2000 (players=34) [10.2s]
#       ... RS progress 600/2000 (players=34) [12.2s]
#       ... RS progress 700/2000 (players=34) [14.2s]
#       ... RS progress 800/2000 (players=34) [16.1s]
#       ... RS progress 900/2000 (players=34) [18.0s]
#       ... RS progress 1000/2000 (players=34) [20.1s]
#       ... RS progress 1100/2000 (players=34) [22.0s]
#       ... RS progress 1200/2000 (players=34) [23.9s]
#       ... RS progress 1300/2000 (players=34) [25.9s]
#       ... RS progress 1400/2000 (players=34) [27.6s]
#       ... RS progress 1500/2000 (players=34) [29.6s]
#       ... RS progress 1600/2000 (players=34) [31.5s]
#       ... RS progress 1700/2000 (players=34) [33.3s]
#       ... RS progress 1800/2000 (players=34) [35.2s]
#       ... RS progress 1900/2000 (players=34) [37.1s]
#       ... RS progress 2000/2000 (players=34) [39.1s]
# [04/36] DONE
#
# [05/36] log=bpi_2012, noise=0.25, property=liveness -> START
#       ... MC progress 25/1000 (players=34, cached=811) [11.3s]
#       ... MC progress 50/1000 (players=34, cached=1599) [22.1s]
#       ... MC progress 75/1000 (players=34, cached=2377) [32.4s]
#       ... MC progress 100/1000 (players=34, cached=3154) [42.4s]
#       ... MC progress 125/1000 (players=34, cached=3917) [51.8s]
#       ... MC progress 150/1000 (players=34, cached=4679) [61.3s]
#       ... MC progress 175/1000 (players=34, cached=5436) [70.4s]
#       ... MC progress 200/1000 (players=34, cached=6192) [79.4s]
#       ... MC progress 225/1000 (players=34, cached=6951) [88.8s]
#       ... MC progress 250/1000 (players=34, cached=7706) [97.6s]
#       ... MC progress 275/1000 (players=34, cached=8464) [106.4s]
#       ... MC progress 300/1000 (players=34, cached=9211) [115.2s]
#       ... MC progress 325/1000 (players=34, cached=9963) [123.9s]
#       ... MC progress 350/1000 (players=34, cached=10711) [132.6s]
#       ... MC progress 375/1000 (players=34, cached=11454) [141.4s]
#       ... MC progress 400/1000 (players=34, cached=12198) [149.7s]
#       ... MC progress 425/1000 (players=34, cached=12942) [158.2s]
#       ... MC progress 450/1000 (players=34, cached=13686) [166.4s]
#       ... MC progress 475/1000 (players=34, cached=14425) [174.9s]
#       ... MC progress 500/1000 (players=34, cached=15170) [183.1s]
#       ... MC progress 525/1000 (players=34, cached=15900) [191.1s]
#       ... MC progress 550/1000 (players=34, cached=16636) [199.3s]
#       ... MC progress 575/1000 (players=34, cached=17377) [207.3s]
#       ... MC progress 600/1000 (players=34, cached=18121) [215.3s]
#       ... MC progress 625/1000 (players=34, cached=18861) [223.1s]
#       ... MC progress 650/1000 (players=34, cached=19598) [231.2s]
#       ... MC progress 675/1000 (players=34, cached=20333) [239.1s]
#       ... MC progress 700/1000 (players=34, cached=21066) [247.2s]
#       ... MC progress 725/1000 (players=34, cached=21799) [254.9s]
#       ... MC progress 750/1000 (players=34, cached=22528) [262.9s]
#       ... MC progress 775/1000 (players=34, cached=23264) [270.7s]
#       ... MC progress 800/1000 (players=34, cached=23998) [278.4s]
#       ... MC progress 825/1000 (players=34, cached=24729) [286.0s]
#       ... MC progress 850/1000 (players=34, cached=25458) [293.6s]
#       ... MC progress 875/1000 (players=34, cached=26186) [301.4s]
#       ... MC progress 900/1000 (players=34, cached=26917) [309.2s]
#       ... MC progress 925/1000 (players=34, cached=27641) [317.1s]
#       ... MC progress 950/1000 (players=34, cached=28375) [324.3s]
#       ... MC progress 975/1000 (players=34, cached=29101) [331.6s]
#       ... MC progress 1000/1000 (players=34, cached=29830) [338.9s]
#       ... RS progress 100/2000 (players=34) [2.0s]
#       ... RS progress 200/2000 (players=34) [4.1s]
#       ... RS progress 300/2000 (players=34) [6.1s]
#       ... RS progress 400/2000 (players=34) [8.2s]
#       ... RS progress 500/2000 (players=34) [10.2s]
#       ... RS progress 600/2000 (players=34) [12.2s]
#       ... RS progress 700/2000 (players=34) [14.2s]
#       ... RS progress 800/2000 (players=34) [16.0s]
#       ... RS progress 900/2000 (players=34) [17.9s]
#       ... RS progress 1000/2000 (players=34) [19.9s]
#       ... RS progress 1100/2000 (players=34) [21.9s]
#       ... RS progress 1200/2000 (players=34) [23.8s]
#       ... RS progress 1300/2000 (players=34) [25.7s]
#       ... RS progress 1400/2000 (players=34) [27.4s]
#       ... RS progress 1500/2000 (players=34) [29.4s]
#       ... RS progress 1600/2000 (players=34) [31.4s]
#       ... RS progress 1700/2000 (players=34) [33.2s]
#       ... RS progress 1800/2000 (players=34) [35.0s]
#       ... RS progress 1900/2000 (players=34) [37.0s]
#       ... RS progress 2000/2000 (players=34) [39.0s]
# [05/36] DONE
#
# [06/36] log=bpi_2012, noise=0.25, property=safety -> START
#       ... MC progress 25/1000 (players=34, cached=811) [10.9s]
#       ... MC progress 50/1000 (players=34, cached=1599) [21.2s]
#       ... MC progress 75/1000 (players=34, cached=2377) [31.2s]
#       ... MC progress 100/1000 (players=34, cached=3154) [40.8s]
#       ... MC progress 125/1000 (players=34, cached=3917) [50.0s]
#       ... MC progress 150/1000 (players=34, cached=4679) [59.4s]
#       ... MC progress 175/1000 (players=34, cached=5436) [68.3s]
#       ... MC progress 200/1000 (players=34, cached=6192) [76.9s]
#       ... MC progress 225/1000 (players=34, cached=6951) [86.1s]
#       ... MC progress 250/1000 (players=34, cached=7706) [94.7s]
#       ... MC progress 275/1000 (players=34, cached=8464) [103.3s]
#       ... MC progress 300/1000 (players=34, cached=9211) [111.9s]
#       ... MC progress 325/1000 (players=34, cached=9963) [120.4s]
#       ... MC progress 350/1000 (players=34, cached=10711) [128.9s]
#       ... MC progress 375/1000 (players=34, cached=11454) [137.2s]
#       ... MC progress 400/1000 (players=34, cached=12198) [145.3s]
#       ... MC progress 425/1000 (players=34, cached=12942) [153.6s]
#       ... MC progress 450/1000 (players=34, cached=13686) [161.7s]
#       ... MC progress 475/1000 (players=34, cached=14425) [169.8s]
#       ... MC progress 500/1000 (players=34, cached=15170) [177.9s]
#       ... MC progress 525/1000 (players=34, cached=15900) [185.7s]
#       ... MC progress 550/1000 (players=34, cached=16636) [193.5s]
#       ... MC progress 575/1000 (players=34, cached=17377) [201.3s]
#       ... MC progress 600/1000 (players=34, cached=18121) [209.1s]
#       ... MC progress 625/1000 (players=34, cached=18861) [216.7s]
#       ... MC progress 650/1000 (players=34, cached=19598) [224.5s]
#       ... MC progress 675/1000 (players=34, cached=20333) [232.3s]
#       ... MC progress 700/1000 (players=34, cached=21066) [240.2s]
#       ... MC progress 725/1000 (players=34, cached=21799) [247.7s]
#       ... MC progress 750/1000 (players=34, cached=22528) [255.4s]
#       ... MC progress 775/1000 (players=34, cached=23264) [263.0s]
#       ... MC progress 800/1000 (players=34, cached=23998) [270.5s]
#       ... MC progress 825/1000 (players=34, cached=24729) [278.0s]
#       ... MC progress 850/1000 (players=34, cached=25458) [285.4s]
#       ... MC progress 875/1000 (players=34, cached=26186) [293.2s]
#       ... MC progress 900/1000 (players=34, cached=26917) [300.9s]
#       ... MC progress 925/1000 (players=34, cached=27641) [308.5s]
#       ... MC progress 950/1000 (players=34, cached=28375) [315.6s]
#       ... MC progress 975/1000 (players=34, cached=29101) [322.7s]
#       ... MC progress 1000/1000 (players=34, cached=29830) [329.8s]
#       ... RS progress 100/2000 (players=34) [1.9s]
#       ... RS progress 200/2000 (players=34) [4.0s]
#       ... RS progress 300/2000 (players=34) [5.9s]
#       ... RS progress 400/2000 (players=34) [7.8s]
#       ... RS progress 500/2000 (players=34) [9.8s]
#       ... RS progress 600/2000 (players=34) [11.7s]
#       ... RS progress 700/2000 (players=34) [13.6s]
#       ... RS progress 800/2000 (players=34) [15.4s]
#       ... RS progress 900/2000 (players=34) [17.2s]
#       ... RS progress 1000/2000 (players=34) [19.2s]
#       ... RS progress 1100/2000 (players=34) [21.1s]
#       ... RS progress 1200/2000 (players=34) [22.9s]
#       ... RS progress 1300/2000 (players=34) [24.8s]
#       ... RS progress 1400/2000 (players=34) [26.4s]
#       ... RS progress 1500/2000 (players=34) [28.4s]
#       ... RS progress 1600/2000 (players=34) [30.2s]
#       ... RS progress 1700/2000 (players=34) [31.9s]
#       ... RS progress 1800/2000 (players=34) [33.7s]
#       ... RS progress 1900/2000 (players=34) [35.6s]
#       ... RS progress 2000/2000 (players=34) [37.5s]
# [06/36] DONE
#
# [07/36] log=bpi_2012, noise=0.5, property=satisfiability -> START
#       ... MC progress 25/1000 (players=30, cached=710) [9.1s]
#       ... MC progress 50/1000 (players=30, cached=1397) [17.1s]
#       ... MC progress 75/1000 (players=30, cached=2067) [24.6s]
#       ... MC progress 100/1000 (players=30, cached=2731) [31.7s]
#       ... MC progress 125/1000 (players=30, cached=3396) [38.7s]
#       ... MC progress 150/1000 (players=30, cached=4057) [45.8s]
#       ... MC progress 175/1000 (players=30, cached=4715) [52.7s]
#       ... MC progress 200/1000 (players=30, cached=5370) [59.1s]
#       ... MC progress 225/1000 (players=30, cached=6019) [65.6s]
#       ... MC progress 250/1000 (players=30, cached=6674) [72.0s]
#       ... MC progress 275/1000 (players=30, cached=7320) [78.2s]
#       ... MC progress 300/1000 (players=30, cached=7969) [84.6s]
#       ... MC progress 325/1000 (players=30, cached=8612) [90.9s]
#       ... MC progress 350/1000 (players=30, cached=9260) [96.7s]
#       ... MC progress 375/1000 (players=30, cached=9897) [102.2s]
#       ... MC progress 400/1000 (players=30, cached=10539) [107.9s]
#       ... MC progress 425/1000 (players=30, cached=11181) [113.7s]
#       ... MC progress 450/1000 (players=30, cached=11816) [119.3s]
#       ... MC progress 475/1000 (players=30, cached=12453) [124.9s]
#       ... MC progress 500/1000 (players=30, cached=13082) [130.2s]
#       ... MC progress 525/1000 (players=30, cached=13712) [135.7s]
#       ... MC progress 550/1000 (players=30, cached=14340) [141.0s]
#       ... MC progress 575/1000 (players=30, cached=14979) [145.9s]
#       ... MC progress 600/1000 (players=30, cached=15607) [151.3s]
#       ... MC progress 625/1000 (players=30, cached=16234) [156.6s]
#       ... MC progress 650/1000 (players=30, cached=16860) [161.6s]
#       ... MC progress 675/1000 (players=30, cached=17481) [166.6s]
#       ... MC progress 700/1000 (players=30, cached=18114) [171.7s]
#       ... MC progress 725/1000 (players=30, cached=18736) [176.7s]
#       ... MC progress 750/1000 (players=30, cached=19364) [181.8s]
#       ... MC progress 775/1000 (players=30, cached=19987) [186.4s]
#       ... MC progress 800/1000 (players=30, cached=20603) [191.2s]
#       ... MC progress 825/1000 (players=30, cached=21225) [196.0s]
#       ... MC progress 850/1000 (players=30, cached=21846) [200.8s]
#       ... MC progress 875/1000 (players=30, cached=22469) [205.7s]
#       ... MC progress 900/1000 (players=30, cached=23085) [210.4s]
#       ... MC progress 925/1000 (players=30, cached=23703) [215.2s]
#       ... MC progress 950/1000 (players=30, cached=24325) [219.9s]
#       ... MC progress 975/1000 (players=30, cached=24940) [224.7s]
#       ... MC progress 1000/1000 (players=30, cached=25554) [229.1s]
#       ... RS progress 100/2000 (players=30) [1.2s]
#       ... RS progress 200/2000 (players=30) [2.4s]
#       ... RS progress 300/2000 (players=30) [3.9s]
#       ... RS progress 400/2000 (players=30) [5.2s]
#       ... RS progress 500/2000 (players=30) [6.4s]
#       ... RS progress 600/2000 (players=30) [7.6s]
#       ... RS progress 700/2000 (players=30) [8.7s]
#       ... RS progress 800/2000 (players=30) [10.0s]
#       ... RS progress 900/2000 (players=30) [11.3s]
#       ... RS progress 1000/2000 (players=30) [12.4s]
#       ... RS progress 1100/2000 (players=30) [13.4s]
#       ... RS progress 1200/2000 (players=30) [14.6s]
#       ... RS progress 1300/2000 (players=30) [15.7s]
#       ... RS progress 1400/2000 (players=30) [16.8s]
#       ... RS progress 1500/2000 (players=30) [18.1s]
#       ... RS progress 1600/2000 (players=30) [19.4s]
#       ... RS progress 1700/2000 (players=30) [20.5s]
#       ... RS progress 1800/2000 (players=30) [21.7s]
#       ... RS progress 1900/2000 (players=30) [22.8s]
#       ... RS progress 2000/2000 (players=30) [24.2s]
# [07/36] DONE
#
# [08/36] log=bpi_2012, noise=0.5, property=liveness -> START
#       ... MC progress 25/1000 (players=30, cached=710) [9.1s]
#       ... MC progress 50/1000 (players=30, cached=1397) [17.2s]
#       ... MC progress 75/1000 (players=30, cached=2067) [24.7s]
#       ... MC progress 100/1000 (players=30, cached=2731) [31.8s]
#       ... MC progress 125/1000 (players=30, cached=3396) [38.8s]
#       ... MC progress 150/1000 (players=30, cached=4057) [45.9s]
#       ... MC progress 175/1000 (players=30, cached=4715) [52.7s]
#       ... MC progress 200/1000 (players=30, cached=5370) [59.1s]
#       ... MC progress 225/1000 (players=30, cached=6019) [65.7s]
#       ... MC progress 250/1000 (players=30, cached=6674) [72.1s]
#       ... MC progress 275/1000 (players=30, cached=7320) [78.2s]
#       ... MC progress 300/1000 (players=30, cached=7969) [84.7s]
#       ... MC progress 325/1000 (players=30, cached=8612) [90.9s]
#       ... MC progress 350/1000 (players=30, cached=9260) [96.7s]
#       ... MC progress 375/1000 (players=30, cached=9897) [102.4s]
#       ... MC progress 400/1000 (players=30, cached=10539) [108.3s]
#       ... MC progress 425/1000 (players=30, cached=11181) [114.1s]
#       ... MC progress 450/1000 (players=30, cached=11816) [119.8s]
#       ... MC progress 475/1000 (players=30, cached=12453) [125.3s]
#       ... MC progress 500/1000 (players=30, cached=13082) [130.7s]
#       ... MC progress 525/1000 (players=30, cached=13712) [136.2s]
#       ... MC progress 550/1000 (players=30, cached=14340) [141.4s]
#       ... MC progress 575/1000 (players=30, cached=14979) [146.3s]
#       ... MC progress 600/1000 (players=30, cached=15607) [151.7s]
#       ... MC progress 625/1000 (players=30, cached=16234) [157.1s]
#       ... MC progress 650/1000 (players=30, cached=16860) [162.1s]
#       ... MC progress 675/1000 (players=30, cached=17481) [167.1s]
#       ... MC progress 700/1000 (players=30, cached=18114) [172.1s]
#       ... MC progress 725/1000 (players=30, cached=18736) [177.1s]
#       ... MC progress 750/1000 (players=30, cached=19364) [182.3s]
#       ... MC progress 775/1000 (players=30, cached=19987) [186.8s]
#       ... MC progress 800/1000 (players=30, cached=20603) [191.7s]
#       ... MC progress 825/1000 (players=30, cached=21225) [196.4s]
#       ... MC progress 850/1000 (players=30, cached=21846) [201.2s]
#       ... MC progress 875/1000 (players=30, cached=22469) [206.1s]
#       ... MC progress 900/1000 (players=30, cached=23085) [210.8s]
#       ... MC progress 925/1000 (players=30, cached=23703) [215.6s]
#       ... MC progress 950/1000 (players=30, cached=24325) [220.4s]
#       ... MC progress 975/1000 (players=30, cached=24940) [225.1s]
#       ... MC progress 1000/1000 (players=30, cached=25554) [229.5s]
#       ... RS progress 100/2000 (players=30) [1.2s]
#       ... RS progress 200/2000 (players=30) [2.3s]
#       ... RS progress 300/2000 (players=30) [3.8s]
#       ... RS progress 400/2000 (players=30) [5.1s]
#       ... RS progress 500/2000 (players=30) [6.3s]
#       ... RS progress 600/2000 (players=30) [7.5s]
#       ... RS progress 700/2000 (players=30) [8.6s]
#       ... RS progress 800/2000 (players=30) [9.9s]
#       ... RS progress 900/2000 (players=30) [11.2s]
#       ... RS progress 1000/2000 (players=30) [12.3s]
#       ... RS progress 1100/2000 (players=30) [13.3s]
#       ... RS progress 1200/2000 (players=30) [14.5s]
#       ... RS progress 1300/2000 (players=30) [15.6s]
#       ... RS progress 1400/2000 (players=30) [16.8s]
#       ... RS progress 1500/2000 (players=30) [18.0s]
#       ... RS progress 1600/2000 (players=30) [19.3s]
#       ... RS progress 1700/2000 (players=30) [20.5s]
#       ... RS progress 1800/2000 (players=30) [21.6s]
#       ... RS progress 1900/2000 (players=30) [22.7s]
#       ... RS progress 2000/2000 (players=30) [24.1s]
# [08/36] DONE
#
# [09/36] log=bpi_2012, noise=0.5, property=safety -> START
#       ... MC progress 25/1000 (players=30, cached=710) [8.8s]
#       ... MC progress 50/1000 (players=30, cached=1397) [16.7s]
#       ... MC progress 75/1000 (players=30, cached=2067) [24.0s]
#       ... MC progress 100/1000 (players=30, cached=2731) [30.8s]
#       ... MC progress 125/1000 (players=30, cached=3396) [37.6s]
#       ... MC progress 150/1000 (players=30, cached=4057) [44.5s]
#       ... MC progress 175/1000 (players=30, cached=4715) [51.1s]
#       ... MC progress 200/1000 (players=30, cached=5370) [57.4s]
#       ... MC progress 225/1000 (players=30, cached=6019) [63.7s]
#       ... MC progress 250/1000 (players=30, cached=6674) [69.9s]
#       ... MC progress 275/1000 (players=30, cached=7320) [75.9s]
#       ... MC progress 300/1000 (players=30, cached=7969) [82.2s]
#       ... MC progress 325/1000 (players=30, cached=8612) [88.3s]
#       ... MC progress 350/1000 (players=30, cached=9260) [94.1s]
#       ... MC progress 375/1000 (players=30, cached=9897) [99.5s]
#       ... MC progress 400/1000 (players=30, cached=10539) [105.0s]
#       ... MC progress 425/1000 (players=30, cached=11181) [110.7s]
#       ... MC progress 450/1000 (players=30, cached=11816) [116.2s]
#       ... MC progress 475/1000 (players=30, cached=12453) [121.6s]
#       ... MC progress 500/1000 (players=30, cached=13082) [126.9s]
#       ... MC progress 525/1000 (players=30, cached=13712) [132.2s]
#       ... MC progress 550/1000 (players=30, cached=14340) [137.3s]
#       ... MC progress 575/1000 (players=30, cached=14979) [142.2s]
#       ... MC progress 600/1000 (players=30, cached=15607) [147.6s]
#       ... MC progress 625/1000 (players=30, cached=16234) [152.8s]
#       ... MC progress 650/1000 (players=30, cached=16860) [157.7s]
#       ... MC progress 675/1000 (players=30, cached=17481) [162.5s]
#       ... MC progress 700/1000 (players=30, cached=18114) [167.4s]
#       ... MC progress 725/1000 (players=30, cached=18736) [172.3s]
#       ... MC progress 750/1000 (players=30, cached=19364) [177.4s]
#       ... MC progress 775/1000 (players=30, cached=19987) [181.9s]
#       ... MC progress 800/1000 (players=30, cached=20603) [186.6s]
#       ... MC progress 825/1000 (players=30, cached=21225) [191.3s]
#       ... MC progress 850/1000 (players=30, cached=21846) [196.1s]
#       ... MC progress 875/1000 (players=30, cached=22469) [200.9s]
#       ... MC progress 900/1000 (players=30, cached=23085) [205.6s]
#       ... MC progress 925/1000 (players=30, cached=23703) [210.3s]
#       ... MC progress 950/1000 (players=30, cached=24325) [214.9s]
#       ... MC progress 975/1000 (players=30, cached=24940) [219.5s]
#       ... MC progress 1000/1000 (players=30, cached=25554) [223.9s]
#       ... RS progress 100/2000 (players=30) [1.1s]
#       ... RS progress 200/2000 (players=30) [2.2s]
#       ... RS progress 300/2000 (players=30) [3.6s]
#       ... RS progress 400/2000 (players=30) [4.9s]
#       ... RS progress 500/2000 (players=30) [6.0s]
#       ... RS progress 600/2000 (players=30) [7.2s]
#       ... RS progress 700/2000 (players=30) [8.2s]
#       ... RS progress 800/2000 (players=30) [9.5s]
#       ... RS progress 900/2000 (players=30) [10.7s]
#       ... RS progress 1000/2000 (players=30) [11.8s]
#       ... RS progress 1100/2000 (players=30) [12.8s]
#       ... RS progress 1200/2000 (players=30) [13.9s]
#       ... RS progress 1300/2000 (players=30) [15.0s]
#       ... RS progress 1400/2000 (players=30) [16.1s]
#       ... RS progress 1500/2000 (players=30) [17.3s]
#       ... RS progress 1600/2000 (players=30) [18.5s]
#       ... RS progress 1700/2000 (players=30) [19.6s]
#       ... RS progress 1800/2000 (players=30) [20.7s]
#       ... RS progress 1900/2000 (players=30) [21.8s]
#       ... RS progress 2000/2000 (players=30) [23.1s]
# [09/36] DONE
#
# [10/36] log=bpi_2012, noise=1.0, property=satisfiability -> START
#       ... MC progress 25/1000 (players=8, cached=121) [1.0s]
#       ... MC progress 50/1000 (players=8, cached=175) [1.2s]
#       ... MC progress 75/1000 (players=8, cached=204) [1.2s]
#       ... MC progress 100/1000 (players=8, cached=221) [1.2s]
#       ... MC progress 125/1000 (players=8, cached=229) [1.2s]
#       ... MC progress 150/1000 (players=8, cached=237) [1.2s]
#       ... MC progress 175/1000 (players=8, cached=245) [1.2s]
#       ... MC progress 200/1000 (players=8, cached=247) [1.3s]
#       ... MC progress 225/1000 (players=8, cached=250) [1.3s]
#       ... MC progress 250/1000 (players=8, cached=252) [1.3s]
#       ... MC progress 275/1000 (players=8, cached=254) [1.3s]
#       ... MC progress 300/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 325/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 350/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 375/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 400/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 425/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 450/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 475/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 500/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 525/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 550/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 575/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 600/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 625/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 650/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 675/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 700/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 725/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 750/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 775/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 800/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 825/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 850/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 875/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 900/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 925/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 950/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 975/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 1000/1000 (players=8, cached=256) [1.3s]
#       ... RS progress 100/2000 (players=8) [0.1s]
#       ... RS progress 200/2000 (players=8) [0.1s]
#       ... RS progress 300/2000 (players=8) [0.1s]
#       ... RS progress 400/2000 (players=8) [0.1s]
#       ... RS progress 500/2000 (players=8) [0.1s]
#       ... RS progress 600/2000 (players=8) [0.1s]
#       ... RS progress 700/2000 (players=8) [0.1s]
#       ... RS progress 800/2000 (players=8) [0.1s]
#       ... RS progress 900/2000 (players=8) [0.1s]
#       ... RS progress 1000/2000 (players=8) [0.1s]
#       ... RS progress 1100/2000 (players=8) [0.1s]
#       ... RS progress 1200/2000 (players=8) [0.1s]
#       ... RS progress 1300/2000 (players=8) [0.1s]
#       ... RS progress 1400/2000 (players=8) [0.1s]
#       ... RS progress 1500/2000 (players=8) [0.1s]
#       ... RS progress 1600/2000 (players=8) [0.1s]
#       ... RS progress 1700/2000 (players=8) [0.1s]
#       ... RS progress 1800/2000 (players=8) [0.1s]
#       ... RS progress 1900/2000 (players=8) [0.1s]
#       ... RS progress 2000/2000 (players=8) [0.1s]
# [10/36] DONE
#
# [11/36] log=bpi_2012, noise=1.0, property=liveness -> START
#       ... MC progress 25/1000 (players=8, cached=121) [1.0s]
#       ... MC progress 50/1000 (players=8, cached=175) [1.2s]
#       ... MC progress 75/1000 (players=8, cached=204) [1.2s]
#       ... MC progress 100/1000 (players=8, cached=221) [1.2s]
#       ... MC progress 125/1000 (players=8, cached=229) [1.2s]
#       ... MC progress 150/1000 (players=8, cached=237) [1.2s]
#       ... MC progress 175/1000 (players=8, cached=245) [1.3s]
#       ... MC progress 200/1000 (players=8, cached=247) [1.3s]
#       ... MC progress 225/1000 (players=8, cached=250) [1.3s]
#       ... MC progress 250/1000 (players=8, cached=252) [1.3s]
#       ... MC progress 275/1000 (players=8, cached=254) [1.3s]
#       ... MC progress 300/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 325/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 350/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 375/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 400/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 425/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 450/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 475/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 500/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 525/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 550/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 575/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 600/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 625/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 650/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 675/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 700/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 725/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 750/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 775/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 800/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 825/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 850/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 875/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 900/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 925/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 950/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 975/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 1000/1000 (players=8, cached=256) [1.3s]
#       ... RS progress 100/2000 (players=8) [0.0s]
#       ... RS progress 200/2000 (players=8) [0.1s]
#       ... RS progress 300/2000 (players=8) [0.1s]
#       ... RS progress 400/2000 (players=8) [0.1s]
#       ... RS progress 500/2000 (players=8) [0.1s]
#       ... RS progress 600/2000 (players=8) [0.1s]
#       ... RS progress 700/2000 (players=8) [0.1s]
#       ... RS progress 800/2000 (players=8) [0.1s]
#       ... RS progress 900/2000 (players=8) [0.1s]
#       ... RS progress 1000/2000 (players=8) [0.1s]
#       ... RS progress 1100/2000 (players=8) [0.1s]
#       ... RS progress 1200/2000 (players=8) [0.1s]
#       ... RS progress 1300/2000 (players=8) [0.1s]
#       ... RS progress 1400/2000 (players=8) [0.1s]
#       ... RS progress 1500/2000 (players=8) [0.1s]
#       ... RS progress 1600/2000 (players=8) [0.1s]
#       ... RS progress 1700/2000 (players=8) [0.1s]
#       ... RS progress 1800/2000 (players=8) [0.1s]
#       ... RS progress 1900/2000 (players=8) [0.1s]
#       ... RS progress 2000/2000 (players=8) [0.1s]
# [11/36] DONE
#
# [12/36] log=bpi_2012, noise=1.0, property=safety -> START
#       ... MC progress 25/1000 (players=8, cached=121) [1.0s]
#       ... MC progress 50/1000 (players=8, cached=175) [1.2s]
#       ... MC progress 75/1000 (players=8, cached=204) [1.2s]
#       ... MC progress 100/1000 (players=8, cached=221) [1.2s]
#       ... MC progress 125/1000 (players=8, cached=229) [1.2s]
#       ... MC progress 150/1000 (players=8, cached=237) [1.2s]
#       ... MC progress 175/1000 (players=8, cached=245) [1.2s]
#       ... MC progress 200/1000 (players=8, cached=247) [1.2s]
#       ... MC progress 225/1000 (players=8, cached=250) [1.2s]
#       ... MC progress 250/1000 (players=8, cached=252) [1.2s]
#       ... MC progress 275/1000 (players=8, cached=254) [1.2s]
#       ... MC progress 300/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 325/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 350/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 375/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 400/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 425/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 450/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 475/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 500/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 525/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 550/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 575/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 600/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 625/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 650/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 675/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 700/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 725/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 750/1000 (players=8, cached=256) [1.2s]
#       ... MC progress 775/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 800/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 825/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 850/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 875/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 900/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 925/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 950/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 975/1000 (players=8, cached=256) [1.3s]
#       ... MC progress 1000/1000 (players=8, cached=256) [1.3s]
#       ... RS progress 100/2000 (players=8) [0.1s]
#       ... RS progress 200/2000 (players=8) [0.1s]
#       ... RS progress 300/2000 (players=8) [0.1s]
#       ... RS progress 400/2000 (players=8) [0.1s]
#       ... RS progress 500/2000 (players=8) [0.1s]
#       ... RS progress 600/2000 (players=8) [0.1s]
#       ... RS progress 700/2000 (players=8) [0.1s]
#       ... RS progress 800/2000 (players=8) [0.1s]
#       ... RS progress 900/2000 (players=8) [0.1s]
#       ... RS progress 1000/2000 (players=8) [0.1s]
#       ... RS progress 1100/2000 (players=8) [0.1s]
#       ... RS progress 1200/2000 (players=8) [0.1s]
#       ... RS progress 1300/2000 (players=8) [0.1s]
#       ... RS progress 1400/2000 (players=8) [0.2s]
#       ... RS progress 1500/2000 (players=8) [0.2s]
#       ... RS progress 1600/2000 (players=8) [0.2s]
#       ... RS progress 1700/2000 (players=8) [0.2s]
#       ... RS progress 1800/2000 (players=8) [0.2s]
#       ... RS progress 1900/2000 (players=8) [0.2s]
#       ... RS progress 2000/2000 (players=8) [0.2s]
# [12/36] DONE
#
# [13/36] log=hospital_billing, noise=0.0, property=satisfiability -> START
#       ... MC progress 25/1000 (players=44, cached=1070) [17.1s]
#       ... MC progress 50/1000 (players=44, cached=2113) [33.6s]
#       ... MC progress 75/1000 (players=44, cached=3148) [49.7s]
#       ... MC progress 100/1000 (players=44, cached=4176) [65.6s]
#       ... MC progress 125/1000 (players=44, cached=5198) [81.5s]
#       ... MC progress 150/1000 (players=44, cached=6217) [97.4s]
#       ... MC progress 175/1000 (players=44, cached=7240) [113.1s]
#       ... MC progress 200/1000 (players=44, cached=8256) [128.4s]
#       ... MC progress 225/1000 (players=44, cached=9267) [144.1s]
#       ... MC progress 250/1000 (players=44, cached=10282) [159.5s]
#       ... MC progress 275/1000 (players=44, cached=11291) [174.7s]
#       ... MC progress 300/1000 (players=44, cached=12300) [190.1s]
#       ... MC progress 325/1000 (players=44, cached=13307) [205.2s]
#       ... MC progress 350/1000 (players=44, cached=14311) [220.5s]
#       ... MC progress 375/1000 (players=44, cached=15315) [235.7s]
#       ... MC progress 400/1000 (players=44, cached=16327) [251.2s]
#       ... MC progress 425/1000 (players=44, cached=17341) [267.0s]
#       ... MC progress 450/1000 (players=44, cached=18344) [282.2s]
#       ... MC progress 475/1000 (players=44, cached=19351) [297.4s]
#       ... MC progress 500/1000 (players=44, cached=20357) [312.7s]
#       ... MC progress 525/1000 (players=44, cached=21358) [328.0s]
#       ... MC progress 550/1000 (players=44, cached=22357) [343.2s]
#       ... MC progress 575/1000 (players=44, cached=23362) [358.1s]
#       ... MC progress 600/1000 (players=44, cached=24361) [373.0s]
#       ... MC progress 625/1000 (players=44, cached=25365) [388.1s]
#       ... MC progress 650/1000 (players=44, cached=26364) [402.9s]
#       ... MC progress 675/1000 (players=44, cached=27361) [417.9s]
#       ... MC progress 700/1000 (players=44, cached=28353) [433.1s]
#       ... MC progress 725/1000 (players=44, cached=29351) [448.2s]
#       ... MC progress 750/1000 (players=44, cached=30344) [462.8s]
#       ... MC progress 775/1000 (players=44, cached=31337) [477.6s]
#       ... MC progress 800/1000 (players=44, cached=32341) [492.2s]
#       ... MC progress 825/1000 (players=44, cached=33323) [506.9s]
#       ... MC progress 850/1000 (players=44, cached=34321) [521.9s]
#       ... MC progress 875/1000 (players=44, cached=35298) [536.7s]
#       ... MC progress 900/1000 (players=44, cached=36291) [551.4s]
#       ... MC progress 925/1000 (players=44, cached=37289) [566.6s]
#       ... MC progress 950/1000 (players=44, cached=38283) [581.2s]
#       ... MC progress 975/1000 (players=44, cached=39276) [596.0s]
#       ... MC progress 1000/1000 (players=44, cached=40263) [610.9s]
#       ... RS progress 100/2000 (players=44) [2.8s]
#       ... RS progress 200/2000 (players=44) [5.8s]
#       ... RS progress 300/2000 (players=44) [8.6s]
#       ... RS progress 400/2000 (players=44) [11.4s]
#       ... RS progress 500/2000 (players=44) [14.3s]
#       ... RS progress 600/2000 (players=44) [17.1s]
#       ... RS progress 700/2000 (players=44) [20.0s]
#       ... RS progress 800/2000 (players=44) [22.8s]
#       ... RS progress 900/2000 (players=44) [25.7s]
#       ... RS progress 1000/2000 (players=44) [28.5s]
#       ... RS progress 1100/2000 (players=44) [31.3s]
# ...
#       ... MC progress 725/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 750/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 775/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 800/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 825/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 850/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 875/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 900/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 925/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 950/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 975/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 1000/1000 (players=6, cached=64) [0.0s]
#       ... RS progress 100/2000 (players=6) [0.0s]
#       ... RS progress 200/2000 (players=6) [0.0s]
#       ... RS progress 300/2000 (players=6) [0.0s]
#       ... RS progress 400/2000 (players=6) [0.0s]
#       ... RS progress 500/2000 (players=6) [0.0s]
#       ... RS progress 600/2000 (players=6) [0.0s]
#       ... RS progress 700/2000 (players=6) [0.0s]
#       ... RS progress 800/2000 (players=6) [0.0s]
#       ... RS progress 900/2000 (players=6) [0.0s]
#       ... RS progress 1000/2000 (players=6) [0.0s]
#       ... RS progress 1100/2000 (players=6) [0.1s]
#       ... RS progress 1200/2000 (players=6) [0.1s]
#       ... RS progress 1300/2000 (players=6) [0.1s]
#       ... RS progress 1400/2000 (players=6) [0.1s]
#       ... RS progress 1500/2000 (players=6) [0.1s]
#       ... RS progress 1600/2000 (players=6) [0.1s]
#       ... RS progress 1700/2000 (players=6) [0.1s]
#       ... RS progress 1800/2000 (players=6) [0.1s]
#       ... RS progress 1900/2000 (players=6) [0.1s]
#       ... RS progress 2000/2000 (players=6) [0.1s]
# [32/36] DONE
#
# [33/36] log=running_example, noise=0.5, property=safety -> START
#       ... MC progress 25/1000 (players=6, cached=51) [0.0s]
#       ... MC progress 50/1000 (players=6, cached=62) [0.0s]
#       ... MC progress 75/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 100/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 125/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 150/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 175/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 200/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 225/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 250/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 275/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 300/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 325/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 350/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 375/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 400/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 425/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 450/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 475/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 500/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 525/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 550/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 575/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 600/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 625/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 650/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 675/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 700/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 725/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 750/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 775/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 800/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 825/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 850/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 875/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 900/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 925/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 950/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 975/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 1000/1000 (players=6, cached=64) [0.0s]
#       ... RS progress 100/2000 (players=6) [0.0s]
#       ... RS progress 200/2000 (players=6) [0.0s]
#       ... RS progress 300/2000 (players=6) [0.0s]
#       ... RS progress 400/2000 (players=6) [0.0s]
#       ... RS progress 500/2000 (players=6) [0.0s]
#       ... RS progress 600/2000 (players=6) [0.0s]
#       ... RS progress 700/2000 (players=6) [0.0s]
#       ... RS progress 800/2000 (players=6) [0.0s]
#       ... RS progress 900/2000 (players=6) [0.0s]
#       ... RS progress 1000/2000 (players=6) [0.0s]
#       ... RS progress 1100/2000 (players=6) [0.0s]
#       ... RS progress 1200/2000 (players=6) [0.0s]
#       ... RS progress 1300/2000 (players=6) [0.0s]
#       ... RS progress 1400/2000 (players=6) [0.0s]
#       ... RS progress 1500/2000 (players=6) [0.0s]
#       ... RS progress 1600/2000 (players=6) [0.0s]
#       ... RS progress 1700/2000 (players=6) [0.0s]
#       ... RS progress 1800/2000 (players=6) [0.0s]
#       ... RS progress 1900/2000 (players=6) [0.0s]
#       ... RS progress 2000/2000 (players=6) [0.0s]
# [33/36] DONE
#
# [34/36] log=running_example, noise=1.0, property=satisfiability -> START
#       ... MC progress 25/1000 (players=6, cached=51) [0.0s]
#       ... MC progress 50/1000 (players=6, cached=62) [0.0s]
#       ... MC progress 75/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 100/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 125/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 150/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 175/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 200/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 225/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 250/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 275/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 300/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 325/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 350/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 375/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 400/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 425/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 450/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 475/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 500/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 525/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 550/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 575/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 600/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 625/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 650/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 675/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 700/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 725/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 750/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 775/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 800/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 825/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 850/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 875/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 900/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 925/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 950/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 975/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 1000/1000 (players=6, cached=64) [0.0s]
#       ... RS progress 100/2000 (players=6) [0.0s]
#       ... RS progress 200/2000 (players=6) [0.0s]
#       ... RS progress 300/2000 (players=6) [0.0s]
#       ... RS progress 400/2000 (players=6) [0.0s]
#       ... RS progress 500/2000 (players=6) [0.0s]
#       ... RS progress 600/2000 (players=6) [0.0s]
#       ... RS progress 700/2000 (players=6) [0.0s]
#       ... RS progress 800/2000 (players=6) [0.0s]
#       ... RS progress 900/2000 (players=6) [0.0s]
#       ... RS progress 1000/2000 (players=6) [0.0s]
#       ... RS progress 1100/2000 (players=6) [0.0s]
#       ... RS progress 1200/2000 (players=6) [0.0s]
#       ... RS progress 1300/2000 (players=6) [0.0s]
#       ... RS progress 1400/2000 (players=6) [0.0s]
#       ... RS progress 1500/2000 (players=6) [0.0s]
#       ... RS progress 1600/2000 (players=6) [0.0s]
#       ... RS progress 1700/2000 (players=6) [0.0s]
#       ... RS progress 1800/2000 (players=6) [0.0s]
#       ... RS progress 1900/2000 (players=6) [0.0s]
#       ... RS progress 2000/2000 (players=6) [0.0s]
# [34/36] DONE
#
# [35/36] log=running_example, noise=1.0, property=liveness -> START
#       ... MC progress 25/1000 (players=6, cached=51) [0.0s]
#       ... MC progress 50/1000 (players=6, cached=62) [0.0s]
#       ... MC progress 75/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 100/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 125/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 150/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 175/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 200/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 225/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 250/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 275/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 300/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 325/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 350/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 375/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 400/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 425/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 450/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 475/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 500/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 525/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 550/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 575/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 600/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 625/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 650/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 675/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 700/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 725/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 750/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 775/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 800/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 825/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 850/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 875/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 900/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 925/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 950/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 975/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 1000/1000 (players=6, cached=64) [0.0s]
#       ... RS progress 100/2000 (players=6) [0.0s]
#       ... RS progress 200/2000 (players=6) [0.0s]
#       ... RS progress 300/2000 (players=6) [0.0s]
#       ... RS progress 400/2000 (players=6) [0.0s]
#       ... RS progress 500/2000 (players=6) [0.0s]
#       ... RS progress 600/2000 (players=6) [0.0s]
#       ... RS progress 700/2000 (players=6) [0.0s]
#       ... RS progress 800/2000 (players=6) [0.0s]
#       ... RS progress 900/2000 (players=6) [0.0s]
#       ... RS progress 1000/2000 (players=6) [0.0s]
#       ... RS progress 1100/2000 (players=6) [0.0s]
#       ... RS progress 1200/2000 (players=6) [0.0s]
#       ... RS progress 1300/2000 (players=6) [0.0s]
#       ... RS progress 1400/2000 (players=6) [0.0s]
#       ... RS progress 1500/2000 (players=6) [0.0s]
#       ... RS progress 1600/2000 (players=6) [0.0s]
#       ... RS progress 1700/2000 (players=6) [0.0s]
#       ... RS progress 1800/2000 (players=6) [0.0s]
#       ... RS progress 1900/2000 (players=6) [0.0s]
#       ... RS progress 2000/2000 (players=6) [0.0s]
# [35/36] DONE
#
# [36/36] log=running_example, noise=1.0, property=safety -> START
#       ... MC progress 25/1000 (players=6, cached=51) [0.0s]
#       ... MC progress 50/1000 (players=6, cached=62) [0.0s]
#       ... MC progress 75/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 100/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 125/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 150/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 175/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 200/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 225/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 250/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 275/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 300/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 325/1000 (players=6, cached=64) [0.0s]
#       ... MC progress 350/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 375/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 400/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 425/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 450/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 475/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 500/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 525/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 550/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 575/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 600/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 625/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 650/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 675/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 700/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 725/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 750/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 775/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 800/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 825/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 850/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 875/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 900/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 925/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 950/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 975/1000 (players=6, cached=64) [0.1s]
#       ... MC progress 1000/1000 (players=6, cached=64) [0.1s]
#       ... RS progress 100/2000 (players=6) [0.0s]
#       ... RS progress 200/2000 (players=6) [0.0s]
#       ... RS progress 300/2000 (players=6) [0.0s]
#       ... RS progress 400/2000 (players=6) [0.0s]
#       ... RS progress 500/2000 (players=6) [0.0s]
#       ... RS progress 600/2000 (players=6) [0.0s]
#       ... RS progress 700/2000 (players=6) [0.0s]
#       ... RS progress 800/2000 (players=6) [0.0s]
#       ... RS progress 900/2000 (players=6) [0.0s]
#       ... RS progress 1000/2000 (players=6) [0.0s]
#       ... RS progress 1100/2000 (players=6) [0.0s]
#       ... RS progress 1200/2000 (players=6) [0.0s]
#       ... RS progress 1300/2000 (players=6) [0.0s]
#       ... RS progress 1400/2000 (players=6) [0.0s]
#       ... RS progress 1500/2000 (players=6) [0.0s]
#       ... RS progress 1600/2000 (players=6) [0.0s]
#       ... RS progress 1700/2000 (players=6) [0.0s]
#       ... RS progress 1800/2000 (players=6) [0.0s]
#       ... RS progress 1900/2000 (players=6) [0.0s]
#       ... RS progress 2000/2000 (players=6) [0.0s]
# [36/36] DONE
#
# [CACHE] Saved 36 configs to ../Docs/Problems/shapley_values/shapley/shapley_results.json

# %% [markdown]
# ## Podsumowanie wyników

# %%
# Wyświetl podsumowanie
print("=== SUMMARY (all configurations) ===")
for i, r in enumerate(SHAPLEY_RESULTS, start=1):
    mc = r["mc_meta"]
    rs = r["rs_meta"]
    print(f"{i:02d}. {r['log']:<18} noise={r['noise']:<4} prop={r['property']:<14} "
          f"| MC avg v={mc['avg_value']:.3f} perms={mc['n_perm']} "
          f"| RS avg v={rs['avg_value']:.3f} samples={rs['n_samples']}")
# Out:
# === SUMMARY (all configurations) ===
# 01. bpi_2012           noise=0.0  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.176 samples=2000
# 02. bpi_2012           noise=0.0  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=0.198 samples=2000
# 03. bpi_2012           noise=0.0  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 04. bpi_2012           noise=0.25 prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.149 samples=2000
# 05. bpi_2012           noise=0.25 prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=0.176 samples=2000
# 06. bpi_2012           noise=0.25 prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 07. bpi_2012           noise=0.5  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.293 samples=2000
# 08. bpi_2012           noise=0.5  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=0.330 samples=2000
# 09. bpi_2012           noise=0.5  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 10. bpi_2012           noise=1.0  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=1.000 samples=2000
# 11. bpi_2012           noise=1.0  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=1.000 samples=2000
# 12. bpi_2012           noise=1.0  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 13. hospital_billing   noise=0.0  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.156 samples=2000
# 14. hospital_billing   noise=0.0  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=0.706 samples=2000
# 15. hospital_billing   noise=0.0  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 16. hospital_billing   noise=0.25 prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.044 samples=2000
# 17. hospital_billing   noise=0.25 prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=0.756 samples=2000
# 18. hospital_billing   noise=0.25 prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 19. hospital_billing   noise=0.5  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.073 samples=2000
# 20. hospital_billing   noise=0.5  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=0.768 samples=2000
# 21. hospital_billing   noise=0.5  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 22. hospital_billing   noise=1.0  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.524 samples=2000
# 23. hospital_billing   noise=1.0  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=1.000 samples=2000
# 24. hospital_billing   noise=1.0  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 25. running_example    noise=0.0  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.852 samples=2000
# 26. running_example    noise=0.0  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=1.000 samples=2000
# 27. running_example    noise=0.0  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 28. running_example    noise=0.25 prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.852 samples=2000
# 29. running_example    noise=0.25 prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=1.000 samples=2000
# 30. running_example    noise=0.25 prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 31. running_example    noise=0.5  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.852 samples=2000
# 32. running_example    noise=0.5  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=1.000 samples=2000
# 33. running_example    noise=0.5  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000
# 34. running_example    noise=1.0  prop=satisfiability | MC avg v=1.000 perms=1000 | RS avg v=0.852 samples=2000
# 35. running_example    noise=1.0  prop=liveness       | MC avg v=1.000 perms=1000 | RS avg v=1.000 samples=2000
# 36. running_example    noise=1.0  prop=safety         | MC avg v=0.000 perms=1000 | RS avg v=0.000 samples=2000

# %% [markdown]
# ## Analiza konwergencji wartości Shapleya

# %%
CONVERGENCE_CONFIGS = [
    {"log": log_name, "noise": noise, "property": prop}
    for log_name in LOG_PATHS.keys()
    for noise in NOISE_LEVELS
    for prop in ["satisfiability", "liveness", "safety"]
]

print(f"Logs: {list(LOG_PATHS.keys())}")
print(f"Noise levels: {NOISE_LEVELS}")
print(f"Properties: satisfiability, liveness, safety")

CONVERGENCE_STEPS = [50, 100, 200, 300, 500, 750, 1000]

CONVERGENCE_RESULTS = []

for idx, cfg in enumerate(CONVERGENCE_CONFIGS, start=1):
    log_name = cfg["log"]
    noise = cfg["noise"]
    prop = cfg["property"]
    named_expr = PATTERNS[(log_name, noise)]
    
    print(f"\n[{idx:02d}/36] [Convergence] log={log_name}, noise={noise}, property={prop}")
    
    print(f"   [{idx:02d}/36] MC: running convergence study ...")
    mc_conv = shapley_mc_convergence(
        named_expr, TEMPLATES, prop,
        steps=CONVERGENCE_STEPS,
        seed=3000 + idx,
        progress_every=50
    )
    
    print(f"   [{idx:02d}/36] RS: running convergence study ...")
    rs_conv = shapley_rs_convergence(
        named_expr, TEMPLATES, prop,
        steps=CONVERGENCE_STEPS,
        keep_frac_range=(0.5, 0.8),
        seed=4000 + idx,
        progress_every=100
    )
    
    CONVERGENCE_RESULTS.append({
        "log": log_name,
        "noise": noise,
        "property": prop,
        "mc_convergence": mc_conv,
        "rs_convergence": rs_conv
    })
    
    print(f"   [{idx:02d}/36] DONE\n")

print(f"\n[Convergence] Completed {len(CONVERGENCE_RESULTS)} studies (expected: 36)")
# Out:
# Logs: ['running_example', 'hospital_billing', 'bpi_2012']
# Noise levels: [0.0, 0.25, 0.5, 1.0]
# Properties: satisfiability, liveness, safety
#
# [01/36] [Convergence] log=running_example, noise=0.0, property=satisfiability
#    [01/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=61
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [01/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [01/36] DONE
#
#
# [02/36] [Convergence] log=running_example, noise=0.0, property=liveness
#    [02/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=63
#       ... MC conv 100/1000 cached=63
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [02/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [02/36] DONE
#
#
# [03/36] [Convergence] log=running_example, noise=0.0, property=safety
#    [03/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=61
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [03/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [03/36] DONE
#
#
# [04/36] [Convergence] log=running_example, noise=0.25, property=satisfiability
#    [04/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=62
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [04/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [04/36] DONE
#
#
# [05/36] [Convergence] log=running_example, noise=0.25, property=liveness
#    [05/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=62
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [05/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [05/36] DONE
#
#
# [06/36] [Convergence] log=running_example, noise=0.25, property=safety
#    [06/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=63
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [06/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [06/36] DONE
#
#
# [07/36] [Convergence] log=running_example, noise=0.5, property=satisfiability
#    [07/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=61
#       ... MC conv 100/1000 cached=63
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [07/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [07/36] DONE
#
#
# [08/36] [Convergence] log=running_example, noise=0.5, property=liveness
#    [08/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=61
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [08/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [08/36] DONE
#
#
# [09/36] [Convergence] log=running_example, noise=0.5, property=safety
#    [09/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=60
#       ... MC conv 100/1000 cached=63
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [09/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [09/36] DONE
#
#
# [10/36] [Convergence] log=running_example, noise=1.0, property=satisfiability
#    [10/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=63
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [10/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [10/36] DONE
#
#
# [11/36] [Convergence] log=running_example, noise=1.0, property=liveness
#    [11/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=63
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [11/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [11/36] DONE
#
#
# [12/36] [Convergence] log=running_example, noise=1.0, property=safety
#    [12/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=63
#       ... MC conv 100/1000 cached=64
#       ... MC conv 150/1000 cached=64
#       ... MC conv 200/1000 cached=64
#       ... MC conv 250/1000 cached=64
#       ... MC conv 300/1000 cached=64
#       ... MC conv 350/1000 cached=64
#       ... MC conv 400/1000 cached=64
#       ... MC conv 450/1000 cached=64
#       ... MC conv 500/1000 cached=64
#       ... MC conv 550/1000 cached=64
#       ... MC conv 600/1000 cached=64
#       ... MC conv 650/1000 cached=64
#       ... MC conv 700/1000 cached=64
#       ... MC conv 750/1000 cached=64
#       ... MC conv 800/1000 cached=64
#       ... MC conv 850/1000 cached=64
#       ... MC conv 900/1000 cached=64
#       ... MC conv 950/1000 cached=64
#       ... MC conv 1000/1000 cached=64
#    [12/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [12/36] DONE
#
#
# [13/36] [Convergence] log=hospital_billing, noise=0.0, property=satisfiability
#    [13/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=2119
#       ... MC conv 100/1000 cached=4177
#       ... MC conv 150/1000 cached=6218
#       ... MC conv 200/1000 cached=8248
#       ... MC conv 250/1000 cached=10276
#       ... MC conv 300/1000 cached=12297
#       ... MC conv 350/1000 cached=14313
#       ... MC conv 400/1000 cached=16326
#       ... MC conv 450/1000 cached=18333
#       ... MC conv 500/1000 cached=20345
#       ... MC conv 550/1000 cached=22340
#       ... MC conv 600/1000 cached=24346
#       ... MC conv 650/1000 cached=26350
#       ... MC conv 700/1000 cached=28347
#       ... MC conv 750/1000 cached=30343
#       ... MC conv 800/1000 cached=32334
#       ... MC conv 850/1000 cached=34322
#       ... MC conv 900/1000 cached=36301
#       ... MC conv 950/1000 cached=38293
#       ... MC conv 1000/1000 cached=40276
#    [13/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [13/36] DONE
#
#
# [14/36] [Convergence] log=hospital_billing, noise=0.0, property=liveness
#    [14/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=2109
#       ... MC conv 100/1000 cached=4173
#       ... MC conv 150/1000 cached=6214
#       ... MC conv 200/1000 cached=8249
#       ... MC conv 250/1000 cached=10276
#       ... MC conv 300/1000 cached=12291
#       ... MC conv 350/1000 cached=14308
#       ... MC conv 400/1000 cached=16314
#       ... MC conv 450/1000 cached=18335
#       ... MC conv 500/1000 cached=20338
#       ... MC conv 550/1000 cached=22335
#       ... MC conv 600/1000 cached=24333
#       ... MC conv 650/1000 cached=26331
#       ... MC conv 700/1000 cached=28318
#       ... MC conv 750/1000 cached=30318
#       ... MC conv 800/1000 cached=32303
#       ... MC conv 850/1000 cached=34289
#       ... MC conv 900/1000 cached=36282
#       ... MC conv 950/1000 cached=38255
#       ... MC conv 1000/1000 cached=40237
#    [14/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [14/36] DONE
#
#
# [15/36] [Convergence] log=hospital_billing, noise=0.0, property=safety
#    [15/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=2104
#       ... MC conv 100/1000 cached=4174
#       ... MC conv 150/1000 cached=6216
#       ... MC conv 200/1000 cached=8249
#       ... MC conv 250/1000 cached=10280
#       ... MC conv 300/1000 cached=12306
#       ... MC conv 350/1000 cached=14328
#       ... MC conv 400/1000 cached=16342
#       ... MC conv 450/1000 cached=18346
#       ... MC conv 500/1000 cached=20357
#       ... MC conv 550/1000 cached=22361
#       ... MC conv 600/1000 cached=24365
#       ... MC conv 650/1000 cached=26352
#       ... MC conv 700/1000 cached=28352
#       ... MC conv 750/1000 cached=30348
#       ... MC conv 800/1000 cached=32337
#       ... MC conv 850/1000 cached=34320
#       ... MC conv 900/1000 cached=36309
#       ... MC conv 950/1000 cached=38282
#       ... MC conv 1000/1000 cached=40250
#    [15/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [15/36] DONE
#
#
# [16/36] [Convergence] log=hospital_billing, noise=0.25, property=satisfiability
#    [16/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1547
#       ... MC conv 100/1000 cached=3051
#       ... MC conv 150/1000 cached=4524
#       ... MC conv 200/1000 cached=5991
#       ... MC conv 250/1000 cached=7452
#       ... MC conv 300/1000 cached=8910
#       ... MC conv 350/1000 cached=10357
#       ... MC conv 400/1000 cached=11807
#       ... MC conv 450/1000 cached=13252
#       ... MC conv 500/1000 cached=14684
#       ... MC conv 550/1000 cached=16099
#       ... MC conv 600/1000 cached=17515
#       ... MC conv 650/1000 cached=18940
#       ... MC conv 700/1000 cached=20354
#       ... MC conv 750/1000 cached=21759
#       ... MC conv 800/1000 cached=23166
#       ... MC conv 850/1000 cached=24571
#       ... MC conv 900/1000 cached=25970
#       ... MC conv 950/1000 cached=27377
#       ... MC conv 1000/1000 cached=28774
#    [16/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [16/36] DONE
#
#
# [17/36] [Convergence] log=hospital_billing, noise=0.25, property=liveness
#    [17/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1545
#       ... MC conv 100/1000 cached=3043
#       ... MC conv 150/1000 cached=4514
#       ... MC conv 200/1000 cached=5985
#       ... MC conv 250/1000 cached=7449
#       ... MC conv 300/1000 cached=8903
#       ... MC conv 350/1000 cached=10355
#       ... MC conv 400/1000 cached=11793
#       ... MC conv 450/1000 cached=13228
#       ... MC conv 500/1000 cached=14662
#       ... MC conv 550/1000 cached=16099
#       ... MC conv 600/1000 cached=17516
#       ... MC conv 650/1000 cached=18939
#       ... MC conv 700/1000 cached=20351
#       ... MC conv 750/1000 cached=21759
#       ... MC conv 800/1000 cached=23168
#       ... MC conv 850/1000 cached=24571
#       ... MC conv 900/1000 cached=25973
#       ... MC conv 950/1000 cached=27373
#       ... MC conv 1000/1000 cached=28767
#    [17/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [17/36] DONE
#
#
# [18/36] [Convergence] log=hospital_billing, noise=0.25, property=safety
#    [18/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1551
#       ... MC conv 100/1000 cached=3050
#       ... MC conv 150/1000 cached=4531
#       ... MC conv 200/1000 cached=5994
#       ... MC conv 250/1000 cached=7457
#       ... MC conv 300/1000 cached=8914
#       ... MC conv 350/1000 cached=10364
#       ... MC conv 400/1000 cached=11812
#       ... MC conv 450/1000 cached=13256
#       ... MC conv 500/1000 cached=14688
#       ... MC conv 550/1000 cached=16122
#       ... MC conv 600/1000 cached=17540
#       ... MC conv 650/1000 cached=18960
#       ... MC conv 700/1000 cached=20376
#       ... MC conv 750/1000 cached=21785
#       ... MC conv 800/1000 cached=23187
#       ... MC conv 850/1000 cached=24592
#       ... MC conv 900/1000 cached=25997
#       ... MC conv 950/1000 cached=27396
#       ... MC conv 1000/1000 cached=28792
#    [18/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [18/36] DONE
#
#
# [19/36] [Convergence] log=hospital_billing, noise=0.5, property=satisfiability
#    [19/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1191
#       ... MC conv 100/1000 cached=2326
#       ... MC conv 150/1000 cached=3428
#       ... MC conv 200/1000 cached=4525
#       ... MC conv 250/1000 cached=5615
#       ... MC conv 300/1000 cached=6701
#       ... MC conv 350/1000 cached=7762
#       ... MC conv 400/1000 cached=8818
#       ... MC conv 450/1000 cached=9870
#       ... MC conv 500/1000 cached=10924
#       ... MC conv 550/1000 cached=11978
#       ... MC conv 600/1000 cached=13030
#       ... MC conv 650/1000 cached=14070
#       ... MC conv 700/1000 cached=15111
#       ... MC conv 750/1000 cached=16142
#       ... MC conv 800/1000 cached=17153
#       ... MC conv 850/1000 cached=18174
#       ... MC conv 900/1000 cached=19194
#       ... MC conv 950/1000 cached=20219
#       ... MC conv 1000/1000 cached=21222
#    [19/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [19/36] DONE
#
#
# [20/36] [Convergence] log=hospital_billing, noise=0.5, property=liveness
#    [20/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1189
#       ... MC conv 100/1000 cached=2317
#       ... MC conv 150/1000 cached=3433
#       ... MC conv 200/1000 cached=4534
#       ... MC conv 250/1000 cached=5617
#       ... MC conv 300/1000 cached=6698
#       ... MC conv 350/1000 cached=7759
#       ... MC conv 400/1000 cached=8832
#       ... MC conv 450/1000 cached=9885
#       ... MC conv 500/1000 cached=10943
#       ... MC conv 550/1000 cached=11990
#       ... MC conv 600/1000 cached=13028
#       ... MC conv 650/1000 cached=14061
#       ... MC conv 700/1000 cached=15090
#       ... MC conv 750/1000 cached=16114
#       ... MC conv 800/1000 cached=17138
#       ... MC conv 850/1000 cached=18152
#       ... MC conv 900/1000 cached=19164
#       ... MC conv 950/1000 cached=20190
#       ... MC conv 1000/1000 cached=21210
#    [20/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [20/36] DONE
#
#
# [21/36] [Convergence] log=hospital_billing, noise=0.5, property=safety
#    [21/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1187
#       ... MC conv 100/1000 cached=2307
#       ... MC conv 150/1000 cached=3417
#       ... MC conv 200/1000 cached=4512
#       ... MC conv 250/1000 cached=5616
#       ... MC conv 300/1000 cached=6682
#       ... MC conv 350/1000 cached=7772
#       ... MC conv 400/1000 cached=8834
#       ... MC conv 450/1000 cached=9885
#       ... MC conv 500/1000 cached=10935
#       ... MC conv 550/1000 cached=11974
#       ... MC conv 600/1000 cached=13017
#       ... MC conv 650/1000 cached=14049
#       ... MC conv 700/1000 cached=15079
#       ... MC conv 750/1000 cached=16127
#       ... MC conv 800/1000 cached=17147
#       ... MC conv 850/1000 cached=18186
#       ... MC conv 900/1000 cached=19207
#       ... MC conv 950/1000 cached=20224
#       ... MC conv 1000/1000 cached=21231
#    [21/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [21/36] DONE
#
#
# [22/36] [Convergence] log=hospital_billing, noise=1.0, property=satisfiability
#    [22/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=547
#       ... MC conv 100/1000 cached=1006
#       ... MC conv 150/1000 cached=1432
#       ... MC conv 200/1000 cached=1835
#       ... MC conv 250/1000 cached=2204
#       ... MC conv 300/1000 cached=2560
#       ... MC conv 350/1000 cached=2900
#       ... MC conv 400/1000 cached=3229
#       ... MC conv 450/1000 cached=3525
#       ... MC conv 500/1000 cached=3814
#       ... MC conv 550/1000 cached=4089
#       ... MC conv 600/1000 cached=4385
#       ... MC conv 650/1000 cached=4666
#       ... MC conv 700/1000 cached=4925
#       ... MC conv 750/1000 cached=5177
#       ... MC conv 800/1000 cached=5422
#       ... MC conv 850/1000 cached=5664
#       ... MC conv 900/1000 cached=5889
#       ... MC conv 950/1000 cached=6096
#       ... MC conv 1000/1000 cached=6314
#    [22/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [22/36] DONE
#
#
# [23/36] [Convergence] log=hospital_billing, noise=1.0, property=liveness
#    [23/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=545
#       ... MC conv 100/1000 cached=1001
#       ... MC conv 150/1000 cached=1417
#       ... MC conv 200/1000 cached=1809
#       ... MC conv 250/1000 cached=2183
#       ... MC conv 300/1000 cached=2522
#       ... MC conv 350/1000 cached=2869
#       ... MC conv 400/1000 cached=3186
#       ... MC conv 450/1000 cached=3507
#       ... MC conv 500/1000 cached=3805
#       ... MC conv 550/1000 cached=4086
#       ... MC conv 600/1000 cached=4377
#       ... MC conv 650/1000 cached=4661
#       ... MC conv 700/1000 cached=4922
#       ... MC conv 750/1000 cached=5188
#       ... MC conv 800/1000 cached=5437
#       ... MC conv 850/1000 cached=5668
#       ... MC conv 900/1000 cached=5890
#       ... MC conv 950/1000 cached=6107
#       ... MC conv 1000/1000 cached=6328
#    [23/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [23/36] DONE
#
#
# [24/36] [Convergence] log=hospital_billing, noise=1.0, property=safety
#    [24/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=546
#       ... MC conv 100/1000 cached=1007
#       ... MC conv 150/1000 cached=1428
#       ... MC conv 200/1000 cached=1802
#       ... MC conv 250/1000 cached=2176
#       ... MC conv 300/1000 cached=2531
#       ... MC conv 350/1000 cached=2872
#       ... MC conv 400/1000 cached=3184
#       ... MC conv 450/1000 cached=3505
#       ... MC conv 500/1000 cached=3799
#       ... MC conv 550/1000 cached=4085
#       ... MC conv 600/1000 cached=4357
#       ... MC conv 650/1000 cached=4627
#       ... MC conv 700/1000 cached=4883
#       ... MC conv 750/1000 cached=5124
#       ... MC conv 800/1000 cached=5364
#       ... MC conv 850/1000 cached=5616
#       ... MC conv 900/1000 cached=5845
#       ... MC conv 950/1000 cached=6062
#       ... MC conv 1000/1000 cached=6277
#    [24/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [24/36] DONE
#
#
# [25/36] [Convergence] log=bpi_2012, noise=0.0, property=satisfiability
#    [25/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=2164
#       ... MC conv 100/1000 cached=4279
#       ... MC conv 150/1000 cached=6367
#       ... MC conv 200/1000 cached=8447
#       ... MC conv 250/1000 cached=10521
#       ... MC conv 300/1000 cached=12598
#       ... MC conv 350/1000 cached=14664
#       ... MC conv 400/1000 cached=16724
#       ... MC conv 450/1000 cached=18787
#       ... MC conv 500/1000 cached=20844
#       ... MC conv 550/1000 cached=22891
#       ... MC conv 600/1000 cached=24947
#       ... MC conv 650/1000 cached=27004
#       ... MC conv 700/1000 cached=29046
#       ... MC conv 750/1000 cached=31091
#       ... MC conv 800/1000 cached=33134
#       ... MC conv 850/1000 cached=35169
#       ... MC conv 900/1000 cached=37218
#       ... MC conv 950/1000 cached=39257
#       ... MC conv 1000/1000 cached=41293
#    [25/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [25/36] DONE
#
#
# [26/36] [Convergence] log=bpi_2012, noise=0.0, property=liveness
#    [26/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=2157
#       ... MC conv 100/1000 cached=4271
#       ... MC conv 150/1000 cached=6368
#       ... MC conv 200/1000 cached=8452
#       ... MC conv 250/1000 cached=10526
#       ... MC conv 300/1000 cached=12602
#       ... MC conv 350/1000 cached=14678
#       ... MC conv 400/1000 cached=16746
#       ... MC conv 450/1000 cached=18800
#       ... MC conv 500/1000 cached=20853
#       ... MC conv 550/1000 cached=22908
#       ... MC conv 600/1000 cached=24949
#       ... MC conv 650/1000 cached=27001
#       ... MC conv 700/1000 cached=29043
#       ... MC conv 750/1000 cached=31090
#       ... MC conv 800/1000 cached=33131
#       ... MC conv 850/1000 cached=35157
#       ... MC conv 900/1000 cached=37195
#       ... MC conv 950/1000 cached=39248
#       ... MC conv 1000/1000 cached=41274
#    [26/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [26/36] DONE
#
#
# [27/36] [Convergence] log=bpi_2012, noise=0.0, property=safety
#    [27/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=2167
#       ... MC conv 100/1000 cached=4277
#       ... MC conv 150/1000 cached=6372
#       ... MC conv 200/1000 cached=8450
#       ... MC conv 250/1000 cached=10531
#       ... MC conv 300/1000 cached=12600
#       ... MC conv 350/1000 cached=14669
#       ... MC conv 400/1000 cached=16738
#       ... MC conv 450/1000 cached=18801
#       ... MC conv 500/1000 cached=20867
#       ... MC conv 550/1000 cached=22921
#       ... MC conv 600/1000 cached=24973
#       ... MC conv 650/1000 cached=27017
#       ... MC conv 700/1000 cached=29053
#       ... MC conv 750/1000 cached=31101
#       ... MC conv 800/1000 cached=33131
#       ... MC conv 850/1000 cached=35172
#       ... MC conv 900/1000 cached=37202
#       ... MC conv 950/1000 cached=39240
#       ... MC conv 1000/1000 cached=41260
#    [27/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [27/36] DONE
#
#
# [28/36] [Convergence] log=bpi_2012, noise=0.25, property=satisfiability
#    [28/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1598
#       ... MC conv 100/1000 cached=3151
#       ... MC conv 150/1000 cached=4679
#       ... MC conv 200/1000 cached=6208
#       ... MC conv 250/1000 cached=7726
#       ... MC conv 300/1000 cached=9234
#       ... MC conv 350/1000 cached=10735
#       ... MC conv 400/1000 cached=12239
#       ... MC conv 450/1000 cached=13721
#       ... MC conv 500/1000 cached=15201
#       ... MC conv 550/1000 cached=16685
#       ... MC conv 600/1000 cached=18157
#       ... MC conv 650/1000 cached=19625
#       ... MC conv 700/1000 cached=21094
#       ... MC conv 750/1000 cached=22550
#       ... MC conv 800/1000 cached=24014
#       ... MC conv 850/1000 cached=25476
#       ... MC conv 900/1000 cached=26926
#       ... MC conv 950/1000 cached=28379
#       ... MC conv 1000/1000 cached=29823
#    [28/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [28/36] DONE
#
#
# [29/36] [Convergence] log=bpi_2012, noise=0.25, property=liveness
#    [29/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1601
#       ... MC conv 100/1000 cached=3138
#       ... MC conv 150/1000 cached=4671
#       ... MC conv 200/1000 cached=6192
#       ... MC conv 250/1000 cached=7700
#       ... MC conv 300/1000 cached=9209
#       ... MC conv 350/1000 cached=10703
#       ... MC conv 400/1000 cached=12207
#       ... MC conv 450/1000 cached=13697
#       ... MC conv 500/1000 cached=15182
#       ... MC conv 550/1000 cached=16652
#       ... MC conv 600/1000 cached=18138
#       ... MC conv 650/1000 cached=19597
#       ... MC conv 700/1000 cached=21059
#       ... MC conv 750/1000 cached=22529
#       ... MC conv 800/1000 cached=23990
#       ... MC conv 850/1000 cached=25455
#       ... MC conv 900/1000 cached=26898
#       ... MC conv 950/1000 cached=28350
#       ... MC conv 1000/1000 cached=29809
#    [29/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [29/36] DONE
#
#
# [30/36] [Convergence] log=bpi_2012, noise=0.25, property=safety
#    [30/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1597
#       ... MC conv 100/1000 cached=3142
#       ... MC conv 150/1000 cached=4670
#       ... MC conv 200/1000 cached=6192
#       ... MC conv 250/1000 cached=7704
#       ... MC conv 300/1000 cached=9211
#       ... MC conv 350/1000 cached=10720
#       ... MC conv 400/1000 cached=12224
#       ... MC conv 450/1000 cached=13714
#       ... MC conv 500/1000 cached=15196
#       ... MC conv 550/1000 cached=16673
#       ... MC conv 600/1000 cached=18141
#       ... MC conv 650/1000 cached=19606
#       ... MC conv 700/1000 cached=21069
#       ... MC conv 750/1000 cached=22529
#       ... MC conv 800/1000 cached=23979
#       ... MC conv 850/1000 cached=25441
#       ... MC conv 900/1000 cached=26899
#       ... MC conv 950/1000 cached=28346
#       ... MC conv 1000/1000 cached=29787
#    [30/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [30/36] DONE
#
#
# [31/36] [Convergence] log=bpi_2012, noise=0.5, property=satisfiability
#    [31/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1394
#       ... MC conv 100/1000 cached=2736
#       ... MC conv 150/1000 cached=4062
#       ... MC conv 200/1000 cached=5371
#       ... MC conv 250/1000 cached=6668
#       ... MC conv 300/1000 cached=7963
#       ... MC conv 350/1000 cached=9255
#       ... MC conv 400/1000 cached=10537
#       ... MC conv 450/1000 cached=11808
#       ... MC conv 500/1000 cached=13063
#       ... MC conv 550/1000 cached=14330
#       ... MC conv 600/1000 cached=15587
#       ... MC conv 650/1000 cached=16850
#       ... MC conv 700/1000 cached=18101
#       ... MC conv 750/1000 cached=19346
#       ... MC conv 800/1000 cached=20592
#       ... MC conv 850/1000 cached=21840
#       ... MC conv 900/1000 cached=23078
#       ... MC conv 950/1000 cached=24318
#       ... MC conv 1000/1000 cached=25559
#    [31/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [31/36] DONE
#
#
# [32/36] [Convergence] log=bpi_2012, noise=0.5, property=liveness
#    [32/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1393
#       ... MC conv 100/1000 cached=2744
#       ... MC conv 150/1000 cached=4061
#       ... MC conv 200/1000 cached=5375
#       ... MC conv 250/1000 cached=6672
#       ... MC conv 300/1000 cached=7960
#       ... MC conv 350/1000 cached=9237
#       ... MC conv 400/1000 cached=10517
#       ... MC conv 450/1000 cached=11797
#       ... MC conv 500/1000 cached=13067
#       ... MC conv 550/1000 cached=14337
#       ... MC conv 600/1000 cached=15598
#       ... MC conv 650/1000 cached=16856
#       ... MC conv 700/1000 cached=18101
#       ... MC conv 750/1000 cached=19347
#       ... MC conv 800/1000 cached=20590
#       ... MC conv 850/1000 cached=21843
#       ... MC conv 900/1000 cached=23090
#       ... MC conv 950/1000 cached=24326
#       ... MC conv 1000/1000 cached=25562
#    [32/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [32/36] DONE
#
#
# [33/36] [Convergence] log=bpi_2012, noise=0.5, property=safety
#    [33/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=1397
#       ... MC conv 100/1000 cached=2740
#       ... MC conv 150/1000 cached=4076
#       ... MC conv 200/1000 cached=5389
#       ... MC conv 250/1000 cached=6691
#       ... MC conv 300/1000 cached=7984
#       ... MC conv 350/1000 cached=9271
#       ... MC conv 400/1000 cached=10561
#       ... MC conv 450/1000 cached=11834
#       ... MC conv 500/1000 cached=13105
#       ... MC conv 550/1000 cached=14373
#       ... MC conv 600/1000 cached=15623
#       ... MC conv 650/1000 cached=16875
#       ... MC conv 700/1000 cached=18122
#       ... MC conv 750/1000 cached=19379
#       ... MC conv 800/1000 cached=20629
#       ... MC conv 850/1000 cached=21874
#       ... MC conv 900/1000 cached=23107
#       ... MC conv 950/1000 cached=24349
#       ... MC conv 1000/1000 cached=25587
#    [33/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [33/36] DONE
#
#
# [34/36] [Convergence] log=bpi_2012, noise=1.0, property=satisfiability
#    [34/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=170
#       ... MC conv 100/1000 cached=219
#       ... MC conv 150/1000 cached=237
#       ... MC conv 200/1000 cached=248
#       ... MC conv 250/1000 cached=253
#       ... MC conv 300/1000 cached=254
#       ... MC conv 350/1000 cached=254
#       ... MC conv 400/1000 cached=255
#       ... MC conv 450/1000 cached=255
#       ... MC conv 500/1000 cached=256
#       ... MC conv 550/1000 cached=256
#       ... MC conv 600/1000 cached=256
#       ... MC conv 650/1000 cached=256
#       ... MC conv 700/1000 cached=256
#       ... MC conv 750/1000 cached=256
#       ... MC conv 800/1000 cached=256
#       ... MC conv 850/1000 cached=256
#       ... MC conv 900/1000 cached=256
#       ... MC conv 950/1000 cached=256
#       ... MC conv 1000/1000 cached=256
#    [34/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [34/36] DONE
#
#
# [35/36] [Convergence] log=bpi_2012, noise=1.0, property=liveness
#    [35/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=177
#       ... MC conv 100/1000 cached=222
#       ... MC conv 150/1000 cached=241
#       ... MC conv 200/1000 cached=247
#       ... MC conv 250/1000 cached=252
#       ... MC conv 300/1000 cached=254
#       ... MC conv 350/1000 cached=256
#       ... MC conv 400/1000 cached=256
#       ... MC conv 450/1000 cached=256
#       ... MC conv 500/1000 cached=256
#       ... MC conv 550/1000 cached=256
#       ... MC conv 600/1000 cached=256
#       ... MC conv 650/1000 cached=256
#       ... MC conv 700/1000 cached=256
#       ... MC conv 750/1000 cached=256
#       ... MC conv 800/1000 cached=256
#       ... MC conv 850/1000 cached=256
#       ... MC conv 900/1000 cached=256
#       ... MC conv 950/1000 cached=256
#       ... MC conv 1000/1000 cached=256
#    [35/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [35/36] DONE
#
#
# [36/36] [Convergence] log=bpi_2012, noise=1.0, property=safety
#    [36/36] MC: running convergence study ...
#       ... MC conv 50/1000 cached=160
#       ... MC conv 100/1000 cached=217
#       ... MC conv 150/1000 cached=236
#       ... MC conv 200/1000 cached=248
#       ... MC conv 250/1000 cached=253
#       ... MC conv 300/1000 cached=255
#       ... MC conv 350/1000 cached=255
#       ... MC conv 400/1000 cached=255
#       ... MC conv 450/1000 cached=255
#       ... MC conv 500/1000 cached=256
#       ... MC conv 550/1000 cached=256
#       ... MC conv 600/1000 cached=256
#       ... MC conv 650/1000 cached=256
#       ... MC conv 700/1000 cached=256
#       ... MC conv 750/1000 cached=256
#       ... MC conv 800/1000 cached=256
#       ... MC conv 850/1000 cached=256
#       ... MC conv 900/1000 cached=256
#       ... MC conv 950/1000 cached=256
#       ... MC conv 1000/1000 cached=256
#    [36/36] RS: running convergence study ...
#       ... RS conv 100/1000
#       ... RS conv 200/1000
#       ... RS conv 300/1000
#       ... RS conv 400/1000
#       ... RS conv 500/1000
#       ... RS conv 600/1000
#       ... RS conv 700/1000
#       ... RS conv 800/1000
#       ... RS conv 900/1000
#       ... RS conv 1000/1000
#    [36/36] DONE
#
#
# [Convergence] Completed 36 studies (expected: 36)

# %%
# Wyświetl wyniki konwergencji
print("\n=== CONVERGENCE ANALYSIS ===")
for result in CONVERGENCE_RESULTS:
    log_name = result["log"]
    noise = result["noise"]
    prop = result["property"]
    mc_conv = result["mc_convergence"]
    rs_conv = result["rs_convergence"]
    
    print(f"\n{log_name} (noise={noise}, property={prop}):")
    print(f"  MC: steps={mc_conv['steps']}")
    print(f"      deltas_max: {[f'{d:.4f}' for d in mc_conv['deltas_max']]}")
    print(f"      deltas_l1:  {[f'{d:.4f}' for d in mc_conv['deltas_l1']]}")
    print(f"  RS: steps={rs_conv['steps']}")
    print(f"      deltas_max: {[f'{d:.4f}' for d in rs_conv['deltas_max']]}")
    print(f"      deltas_l1:  {[f'{d:.4f}' for d in rs_conv['deltas_l1']]}")
# Out:
# === CONVERGENCE ANALYSIS ===
#
# running_example (noise=0.0, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0600', '0.0350', '0.0233', '0.0200', '0.0160', '0.0030']
#       deltas_l1:  ['0.0000', '0.1200', '0.0800', '0.0467', '0.0413', '0.0387', '0.0073']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.1349', '0.0839', '0.0458', '0.0315', '0.0308', '0.0515']
#       deltas_l1:  ['0.0000', '0.3550', '0.2985', '0.2074', '0.1029', '0.1228', '0.1512']
#
# running_example (noise=0.0, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# running_example (noise=0.0, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# running_example (noise=0.25, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0400', '0.0350', '0.0133', '0.0260', '0.0113', '0.0043']
#       deltas_l1:  ['0.0000', '0.0800', '0.0700', '0.0300', '0.0520', '0.0240', '0.0120']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.1276', '0.0479', '0.0475', '0.0508', '0.0310', '0.0292']
#       deltas_l1:  ['0.0000', '0.3555', '0.1406', '0.1415', '0.2048', '0.0844', '0.0917']
#
# running_example (noise=0.25, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# running_example (noise=0.25, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# running_example (noise=0.5, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0300', '0.0700', '0.0267', '0.0187', '0.0180', '0.0107']
#       deltas_l1:  ['0.0000', '0.0600', '0.1500', '0.0533', '0.0427', '0.0360', '0.0320']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.1531', '0.0690', '0.0458', '0.0457', '0.0320', '0.0189']
#       deltas_l1:  ['0.0000', '0.4877', '0.2102', '0.1598', '0.1589', '0.1063', '0.0551']
#
# running_example (noise=0.5, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# running_example (noise=0.5, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# running_example (noise=1.0, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.1200', '0.0250', '0.0217', '0.0327', '0.0187', '0.0273']
#       deltas_l1:  ['0.0000', '0.2400', '0.0500', '0.0533', '0.0653', '0.0387', '0.0553']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0991', '0.0354', '0.0579', '0.0423', '0.0333', '0.0180']
#       deltas_l1:  ['0.0000', '0.3901', '0.1407', '0.1740', '0.0926', '0.0964', '0.0494']
#
# running_example (noise=1.0, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# running_example (noise=1.0, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# hospital_billing (noise=0.0, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0300', '0.0200', '0.0200', '0.0140', '0.0090']
#       deltas_l1:  ['0.0000', '0.5400', '0.3900', '0.2233', '0.2080', '0.1613', '0.0960']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2026', '0.1220', '0.0600', '0.0711', '0.0613', '0.0293']
#       deltas_l1:  ['0.0000', '2.8485', '2.0589', '1.2125', '0.9443', '0.6334', '0.6649']
#
# hospital_billing (noise=0.0, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0900', '0.0550', '0.0217', '0.0227', '0.0160', '0.0130']
#       deltas_l1:  ['0.0000', '0.5800', '0.3100', '0.1767', '0.1947', '0.1320', '0.0867']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2035', '0.1146', '0.0888', '0.0776', '0.0485', '0.0396']
#       deltas_l1:  ['0.0000', '2.6988', '2.4294', '1.5166', '1.1124', '0.6995', '0.5485']
#
# hospital_billing (noise=0.0, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# hospital_billing (noise=0.25, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0200', '0.0133', '0.0233', '0.0160', '0.0083']
#       deltas_l1:  ['0.0000', '0.5600', '0.2900', '0.1567', '0.2053', '0.0960', '0.0733']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0810', '0.0751', '0.0479', '0.0322', '0.0231', '0.0172']
#       deltas_l1:  ['0.0000', '1.0689', '0.7420', '0.5192', '0.3489', '0.2139', '0.2191']
#
# hospital_billing (noise=0.25, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0400', '0.0300', '0.0167', '0.0207', '0.0160', '0.0100']
#       deltas_l1:  ['0.0000', '0.3400', '0.3000', '0.1400', '0.1640', '0.1267', '0.0813']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2080', '0.1695', '0.1209', '0.0843', '0.0507', '0.0322']
#       deltas_l1:  ['0.0000', '2.4480', '1.5872', '1.0865', '0.9163', '0.6444', '0.3529']
#
# hospital_billing (noise=0.25, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# hospital_billing (noise=0.5, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0300', '0.0250', '0.0207', '0.0140', '0.0123']
#       deltas_l1:  ['0.0000', '0.4600', '0.2900', '0.1500', '0.1707', '0.0907', '0.0893']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0849', '0.0614', '0.0417', '0.0512', '0.0329', '0.0348']
#       deltas_l1:  ['0.0000', '0.5491', '0.4689', '0.4221', '0.4594', '0.3788', '0.1537']
#
# hospital_billing (noise=0.5, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0250', '0.0267', '0.0340', '0.0200', '0.0110']
#       deltas_l1:  ['0.0000', '0.3000', '0.2500', '0.1467', '0.1453', '0.1027', '0.0800']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.1863', '0.1476', '0.0870', '0.0468', '0.0343', '0.0532']
#       deltas_l1:  ['0.0000', '1.4691', '1.4921', '0.8152', '0.5455', '0.3540', '0.3402']
#
# hospital_billing (noise=0.5, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# hospital_billing (noise=1.0, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0250', '0.0217', '0.0133', '0.0160', '0.0160']
#       deltas_l1:  ['0.0000', '0.2600', '0.0900', '0.0800', '0.0493', '0.0627', '0.0507']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2681', '0.1539', '0.0717', '0.0693', '0.0361', '0.0450']
#       deltas_l1:  ['0.0000', '1.4702', '0.9966', '0.4190', '0.3517', '0.2429', '0.2446']
#
# hospital_billing (noise=1.0, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# hospital_billing (noise=1.0, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# bpi_2012 (noise=0.0, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0400', '0.0250', '0.0200', '0.0280', '0.0193', '0.0077']
#       deltas_l1:  ['0.0000', '0.4400', '0.3700', '0.1333', '0.1907', '0.1360', '0.0840']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2608', '0.0900', '0.0761', '0.0664', '0.0424', '0.0306']
#       deltas_l1:  ['0.0000', '2.8130', '1.6639', '1.0200', '1.0450', '0.6887', '0.4585']
#
# bpi_2012 (noise=0.0, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0350', '0.0333', '0.0140', '0.0080', '0.0083']
#       deltas_l1:  ['0.0000', '0.5200', '0.3500', '0.2267', '0.1160', '0.0933', '0.0680']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2531', '0.1308', '0.0855', '0.0988', '0.0526', '0.0283']
#       deltas_l1:  ['0.0000', '3.6011', '1.9954', '0.9568', '1.2617', '0.7760', '0.4659']
#
# bpi_2012 (noise=0.0, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# bpi_2012 (noise=0.25, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0300', '0.0400', '0.0133', '0.0200', '0.0120', '0.0163']
#       deltas_l1:  ['0.0000', '0.3200', '0.3200', '0.1533', '0.1600', '0.1067', '0.0747']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2078', '0.1143', '0.0544', '0.0562', '0.0392', '0.0280']
#       deltas_l1:  ['0.0000', '2.9775', '1.6310', '0.7037', '0.6408', '0.5105', '0.3799']
#
# bpi_2012 (noise=0.25, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0800', '0.0500', '0.0167', '0.0200', '0.0093', '0.0100']
#       deltas_l1:  ['0.0000', '0.4600', '0.3600', '0.1633', '0.1520', '0.0973', '0.0733']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.1681', '0.1404', '0.0536', '0.0784', '0.0368', '0.0217']
#       deltas_l1:  ['0.0000', '2.0904', '1.2357', '0.5963', '0.7450', '0.5102', '0.3105']
#
# bpi_2012 (noise=0.25, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# bpi_2012 (noise=0.5, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0300', '0.0267', '0.0207', '0.0160', '0.0070']
#       deltas_l1:  ['0.0000', '0.2200', '0.2100', '0.1400', '0.1667', '0.1187', '0.0553']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2037', '0.1459', '0.0939', '0.0611', '0.0548', '0.0427']
#       deltas_l1:  ['0.0000', '2.6983', '1.6357', '0.9501', '0.7838', '0.6314', '0.4092']
#
# bpi_2012 (noise=0.5, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0500', '0.0400', '0.0283', '0.0167', '0.0087', '0.0067']
#       deltas_l1:  ['0.0000', '0.2600', '0.2600', '0.1533', '0.1653', '0.0747', '0.0440']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.2065', '0.1245', '0.0929', '0.0797', '0.0612', '0.0368']
#       deltas_l1:  ['0.0000', '1.6925', '1.3855', '0.9874', '0.7208', '0.6731', '0.3029']
#
# bpi_2012 (noise=0.5, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# bpi_2012 (noise=1.0, property=satisfiability):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# bpi_2012 (noise=1.0, property=liveness):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#
# bpi_2012 (noise=1.0, property=safety):
#   MC: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#   RS: steps=[50, 100, 200, 300, 500, 750, 1000]
#       deltas_max: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']
#       deltas_l1:  ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']

# %%
import matplotlib.pyplot as plt

if CONVERGENCE_RESULTS:
    fig, axes = plt.subplots(len(CONVERGENCE_RESULTS), 2, figsize=(14, 5 * len(CONVERGENCE_RESULTS)))
    if len(CONVERGENCE_RESULTS) == 1:
        axes = axes.reshape(1, -1)
    
    for idx, result in enumerate(CONVERGENCE_RESULTS):
        mc_conv = result["mc_convergence"]
        rs_conv = result["rs_convergence"]
        prop = result["property"]
        
        ax_mc = axes[idx, 0]
        ax_mc.plot(mc_conv['steps'], mc_conv['deltas_max'], 'o-', label='Max abs diff', linewidth=2)
        ax_mc.plot(mc_conv['steps'], mc_conv['deltas_l1'], 's-', label='L1 norm', linewidth=2)
        ax_mc.set_xlabel('Iterations')
        ax_mc.set_ylabel('Convergence metric')
        ax_mc.set_title(f'MC Convergence - {prop}')
        ax_mc.legend()
        ax_mc.grid(True, alpha=0.3)
        ax_mc.set_yscale('log')
        
        ax_rs = axes[idx, 1]
        ax_rs.plot(rs_conv['steps'], rs_conv['deltas_max'], 'o-', label='Max abs diff', linewidth=2)
        ax_rs.plot(rs_conv['steps'], rs_conv['deltas_l1'], 's-', label='L1 norm', linewidth=2)
        ax_rs.set_xlabel('Iterations')
        ax_rs.set_ylabel('Convergence metric')
        ax_rs.set_title(f'RS Convergence - {prop}')
        ax_rs.legend()
        ax_rs.grid(True, alpha=0.3)
        ax_rs.set_yscale('log')
    
    plt.tight_layout()
    plt.show()

# %%
from Functions.players.player_enumeration import _parse_labelled_expression_to_tree
from Functions.utils.imports import Digraph
from collections import defaultdict
from itertools import count

def _build_graphviz_from_tree(tree_dict) -> Digraph:
    """Build Graphviz diagram from tree dictionary with player labels."""
    dot = Digraph(comment="Pattern Tree with Player Labels", format="png")
    dot.attr(rankdir="TB", nodesep="0.2", ranksep="0.3")

    uid = count(1)
    totals = defaultdict(int)

    def tally(node):
        if node.get("type") == "pattern":
            totals[node["id"]] += 1
        for ch in node.get("children", []):
            tally(ch)

    tally(tree_dict)
    seen = defaultdict(int)

    def resolved_label(node_label: str) -> str:
        """Resolve label with occurrence number if multiple instances exist."""
        if totals[node_label] <= 1:
            return node_label
        seen[node_label] += 1
        return f"{node_label}@{seen[node_label]}"

    def add(node) -> str:
        node_id = f"n{next(uid)}"
        if node.get("type") == "pattern":
            label_for_display = resolved_label(node["id"])
            dot.node(node_id, label=label_for_display, shape="box", style="rounded,filled", fillcolor="#eef2ff")
            for ch in node.get("children", []):
                cid = add(ch)
                dot.edge(node_id, cid)
        else:
            txt = str(node.get("text", ""))
            dot.node(node_id, label=txt, shape="ellipse", style="filled", fillcolor="#f8f9fa")
        return node_id

    add(tree_dict)
    return dot


def visualize_named_expression_tree(named_expr: str, *, display_graph: bool = True) -> Digraph:
    """Visualize named expression tree with player labels."""
    tree = _parse_labelled_expression_to_tree(named_expr)
    dot = _build_graphviz_from_tree(tree)
    if display_graph:
        display(dot)
    return dot

# Wyświetl drzewa dla wszystkich konfiguracji
print("=== WIZUALIZACJA DRZEW PROCESU Z LABELLOWANIEM GRACZY ===\n")

# Sprawdź, czy PATTERNS jest zdefiniowane
if "PATTERNS" not in globals() or not PATTERNS:
    print("⚠ PATTERNS nie jest zdefiniowane. Ładowanie danych...")
    try:
        from Functions.data_loading import load_event_log, discover_tree_inductive, assign_tau_labels, LOG_PATHS, NOISE_LEVELS
        from Functions.tree_conversion import tree_to_named_pattern_expression
        
        # Ładowanie logów zdarzeń
        EVENT_LOGS = {}
        for name, path in LOG_PATHS.items():
            EVENT_LOGS[name] = load_event_log(path)
        
        # Odkrywanie drzew procesu
        TREES = {}
        for log_name, log_obj in EVENT_LOGS.items():
            for noise in NOISE_LEVELS:
                tree = discover_tree_inductive(log_obj, noise=noise)
                tree = assign_tau_labels(tree)
                TREES[(log_name, noise)] = tree
        
        # Konwersja drzew na nazwane wyrażenia wzorców
        PATTERNS = {}
        for key, tree in TREES.items():
            named_expr = tree_to_named_pattern_expression(tree)
            PATTERNS[key] = named_expr
        
        print(f"✓ Załadowano PATTERNS ({len(PATTERNS)} konfiguracji)")
    except Exception as e:
        print(f"❌ Błąd podczas ładowania danych: {e}")
        print("Uruchom najpierw wcześniejsze komórki notebooka, aby zdefiniować PATTERNS.")
        raise

if PATTERNS:
    for (log_name, noise), named_expr in sorted(PATTERNS.items(), key=lambda kv: (kv[0][0], kv[0][1])):
        print(f"\n{'='*60}")
        print(f"Log: {log_name}, Noise: {noise}")
        print(f"{'='*60}")
        visualize_named_expression_tree(named_expr)
else:
    print("❌ Brak danych PATTERNS do wyświetlenia.")
# Out:
# === WIZUALIZACJA DRZEW PROCESU Z LABELLOWANIEM GRACZY ===
#
# ⚠ PATTERNS nie jest zdefiniowane. Ładowanie danych...
# parsing log, completed traces ::   0%|          | 0/6 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/100000 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/13087 [00:00<?, ?it/s]
# ✓ Załadowano PATTERNS (12 konfiguracji)
#
# ============================================================
# Log: bpi_2012, Noise: 0.0
# ============================================================
# ============================================================
# Log: bpi_2012, Noise: 0.25
# ============================================================
# ============================================================
# Log: bpi_2012, Noise: 0.5
# ============================================================
# ============================================================
# Log: bpi_2012, Noise: 1.0
# ============================================================
# ============================================================
# Log: hospital_billing, Noise: 0.0
# ============================================================
# ============================================================
# Log: hospital_billing, Noise: 0.25
# ============================================================
# ============================================================
# Log: hospital_billing, Noise: 0.5
# ============================================================
# ============================================================
# Log: hospital_billing, Noise: 1.0
# ============================================================
# ============================================================
# Log: running_example, Noise: 0.0
# ============================================================
# ============================================================
# Log: running_example, Noise: 0.25
# ============================================================
# ============================================================
# Log: running_example, Noise: 0.5
# ============================================================
# ============================================================
# Log: running_example, Noise: 1.0
# ============================================================
